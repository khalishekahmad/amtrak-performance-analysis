# %% [markdown]
# # Explore: Amtrak Network
#
# ## Intercity Passenger Rail Service Station Performance Metrics
#
# The Amtrak [network](https://www.amtrak.com/content/dam/projects/dotcom/english/public/documents/Maps/Amtrak-System-Map-020923.pdf)
# is a passenger rail service that provides intercity rail service in the
# continental United States and to select Canadian cities. The network is operated by the
# [National Railroad Passenger Corporation](https://railroads.dot.gov/passenger-rail/amtrak/amtrak),
# a federally chartered for-profit corporation that receives some state funding and covers its
# operating costs by selling tickets and providing other services.
#
# This notebook commences exploration of the augmented quarterly
# [Amtrak](https://www.amtrak.com/home.html) station performance metrics. The goal is to better
# understand the Amtrak network as a whole and identify potential areas for further analysis.
#
# ### Variable names
#
# A number of variable names in this project leverage the following abbreviations. The naming
# strategy is to strike a balance between brevity and readability:
#
# * `amtk`: Amtrak (reporting mark)
# * `chrt`: chart
# * `cols`: columns
# * `const`: constant
# * `cwd`: current working directory
# * `eb`: eastbound direction of travel
# * `lm`: linear model
# * `mi`: miles
# * `mm`: minutes (ISO 8601)
# * `nb`: northbound direction of travel
# * `psgr`: passenger
# * `qtr`: quarter
# * `rte`: route
# * `sb`: southbound direction of travel
# * `stats`: summary statistics
# * `stn`: station
# * `stns`: stations
# * `svc`: service
# * `trn`: train
# * `wb`: westbound direction of travel

# %%
import numpy as np
import pandas as pd
import pathlib as pl
import scipy.stats as stats
import tomllib as tl

import fra_amtrak.amtk_detrain as detrn
import fra_amtrak.amtk_frame as frm
import fra_amtrak.chart.chart as chrt
import fra_amtrak.chart.builders.bar_grp_bldr as bar_bld
import fra_amtrak.chart.builders.bxplt_preagg_bldr as bxp_bld
import fra_amtrak.chart.builders.hstgrm_bldr as hst_bld
import fra_amtrak.chart.schemas.bar_grp as bar
import fra_amtrak.chart.schemas.bxplt_preagg as bxp
import fra_amtrak.chart.schemas.hstgrm as hst

# %% [markdown]
# ## 1.0 Read files
#
# ### 1.1 Resolve paths

# %%
parent_path = pl.Path.cwd()  # current working directory
parent_path
# Out:
# PosixPath('/home/jovyan/work/assignments/Course4')

# %% [markdown]
# ### 1.2 Load constants
#
# Load a companion [TOML](https://toml.io/en/) file named `notebook.toml` containing constants.

# %%
filepath = parent_path.joinpath("notebook.toml")
with open(filepath, "rb") as file_obj:
    const = tl.load(file_obj)

# Access constants
AGG = const["agg"]
CHRT_BAR = const["chart"]["bar"]
COLORS = const["colors"]
COLS = const["columns"]

# %% [markdown]
# ### 1.3 Retrieve performance data

# %%
filepath = "station_performance_metrics-v1p2.csv"

network = pd.read_csv(
    filepath, dtype={"Address 02": "str", "ZIP Code": "str"}, low_memory=False
)  # avoid DtypeWarning

# %% [markdown]
# ### 1.4 Review the `DataFrame`

# %%
network.shape
# Out:
# (68412, 24)

# %%
network.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68412 entries, 0 to 68411
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Fiscal Year                               68412 non-null  int64
#  1   Fiscal Quarter                            68412 non-null  int64
#  2   Service Line                              68412 non-null  object
#  3   Service                                   68412 non-null  object
#  4   Route Miles                               68412 non-null  int64
#  5   Sub Service                               68412 non-null  object
#  6   Train Number                              68412 non-null  int64
#  7   Arrival Station Code                      68412 non-null  object
#  8   Arrival Station                           68412 non-null  object
#  9   Arrival Station Type                      68386 non-null  object
#  10  City                                      68404 non-null  object
#  11  Address 01                                68404 non-null  object
#  12  Address 02                                126 non-null    object
#  13  ZIP Code                                  68404 non-null  object
#  14  State                                     68412 non-null  object
#  15  Division                                  68354 non-null  object
#  16  Region                                    68354 non-null  object
#  17  Country                                   68354 non-null  object
#  18  Latitude                                  68404 non-null  float64
#  19  Longitude                                 68404 non-null  float64
#  20  Total Detraining Customers                68412 non-null  int64
#  21  Late Detraining Customers                 68412 non-null  int64
#  22  Late to Total Detraining Customers Ratio  68412 non-null  float64
#  23  Late Detraining Customers Avg Min Late    57373 non-null  float64
# dtypes: float64(4), int64(6), object(14)
# memory usage: 12.5+ MB

# %%
network.head(3)
# Out:
#    Fiscal Year  Fiscal Quarter   Service Line            Service  Route Miles  \
# 0         2024               3  Long Distance         Auto Train          914
# 1         2024               3  Long Distance         Auto Train          914
# 2         2024               3  Long Distance  California Zephyr         2408
#
#          Sub Service  Train Number Arrival Station Code       Arrival Station  \
# 0         Auto Train            52                  LOR   Lorton (Auto Train)
# 1         Auto Train            53                  SFA  Sanford (Auto Train)
# 2  California Zephyr             5                  BRL            Burlington
#
#                    Arrival Station Type  ...     State            Division  \
# 0  Station Building (with waiting room)  ...  Virginia      South Atlantic
# 1  Station Building (with waiting room)  ...   Florida      South Atlantic
# 2  Station Building (with waiting room)  ...      Iowa  West North Central
#
#     Region        Country   Latitude  Longitude Total Detraining Customers  \
# 0    South  United States  38.708143 -77.220942                      42445
# 1    South  United States  28.808544 -81.291274                      28034
# 2  Midwest  United States  40.805788 -91.101951                        557
#
#   Late Detraining Customers  Late to Total Detraining Customers Ratio  \
# 0                     23316                                   0.54932
# 1                     18439                                   0.65774
# 2                       223                                   0.40036
#
#    Late Detraining Customers Avg Min Late
# 0                                    95.0
# 1                                    91.0
# 2                                    54.0
#
# [3 rows x 24 columns]

# %% [markdown]
# ## 2.0 The Amtrak network
#
# Network-wide summary statistics covering all available fiscal years and quarters. The data is
# derived by flattening a `DataFrame` into a single row of metrics.

# %%
# Total train arrivals
network_trn_arrivals = network.shape[0]

# Detraining totals
network_detrn = network[COLS["total_detrn"]].sum()
network_detrn_late = network[COLS["late_detrn"]].sum()
network_detrn_on_time = network_detrn - network_detrn_late

print(
    f"Train Arrivals: {network_trn_arrivals}",
    f"Total Detraining Customers: {network_detrn}",
    f"Late Detraining Customers: {network_detrn_late}",
    f"On-Time Detraining Customers: {network_detrn_on_time}",
    sep="\n",
)

# Compute summary statistics
network_stats = detrn.get_sum_stats(network, AGG["columns"], AGG["funcs"])
network_stats
# Out:
# Train Arrivals: 68412
# Total Detraining Customers: 78330934
# Late Detraining Customers: 19425149
# On-Time Detraining Customers: 58905785
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 18
#       9 print(
#      10     f"Train Arrivals: {network_trn_arrivals}",
#      11     f"Total Detraining Customers: {network_detrn}",
#    (...)
#      14     sep="\n",
#      15 )
#      17 # Compute summary statistics
# ---> 18 network_stats = detrn.get_sum_stats(network, AGG["columns"], AGG["funcs"])
#      19 network_stats
#
# File ~/work/assignments/Course4/fra_amtrak/amtk_detrain.py:298, in get_sum_stats(frame, agg_columns, agg_funcs, precision)
#     295 stats = compute_sum_stats(frame, agg_columns, agg_funcs)  # Do not reset index
#     297 # Flatten
# --> 298 stats = stats.unstack().to_frame().transpose()
#     299 # print(f"system stats: {stats}")
#     300
#     301 # Rename
#     302 stats.columns = [f"{col} {idx}" for col, idx in stats.columns]
#
# AttributeError: 'NoneType' object has no attribute 'unstack'

# %% [markdown]
# ### 2.1 Service lines
#
# The Amtrak network consists of several service lines. The service lines are used to group
# services, stations, and train routes. Service line summary statistics cover all available fiscal
# years and quarters and are derived by aggregating metrics across each service line.

# %%
# ── DEBUG: cek AGG config dan kolom CSV ──────────────────────────────────────

print("=== AGG config ===")
print("AGG['columns']:", AGG["columns"])
print("AGG['funcs']  :", AGG["funcs"])

print("\n=== Kolom di network DataFrame ===")
print(network.columns.tolist())

print("\n=== Cek apakah semua kolom AGG ada di network ===")
missing = [col for col in AGG["columns"] if col not in network.columns]
print("Kolom HILANG:", missing if missing else "Tidak ada — semua ada ✓")
# Out:
# === AGG config ===
# AGG['columns']: ['Total Detraining Customers', 'Late Detraining Customers']
# AGG['funcs']  : ['sum', 'mean', 'median', 'std']
#
# === Kolom di network DataFrame ===
# ['Fiscal Year', 'Fiscal Quarter', 'Service Line', 'Service', 'Route Miles', 'Sub Service', 'Train Number', 'Arrival Station Code', 'Arrival Station', 'Arrival Station Type', 'City', 'Address 01', 'Address 02', 'ZIP Code', 'State', 'Division', 'Region', 'Country', 'Latitude', 'Longitude', 'Total Detraining Customers', 'Late Detraining Customers', 'Late to Total Detraining Customers Ratio', 'Late Detraining Customers Avg Min Late']
#
# === Cek apakah semua kolom AGG ada di network ===
# Kolom HILANG: Tidak ada — semua ada ✓

# %%
# ── DEBUG: test compute langsung ─────────────────────────────────────────────
import fra_amtrak.amtk_detrain as detrn
import inspect

# Lihat source code compute_sum_stats
print(inspect.getsource(detrn.compute_sum_stats))
# Out:
# def compute_sum_stats(frame, agg_columns, agg_funcs, precision=4):
#     """Computes summary statistics by constructing a dictionary of aggregation functions to be
#     applied to specified < frame > columns. The < agg_columns > specifies the columns
#     to aggregate, while the < agg_funcs > list specifies the types of functions to apply to each
#     target column.
#
#     The function assembles a dictionary of aggregation functions to apply to the specified columns
#     by iterating over < frame.columns > and mapping the < agg_funcs > list to each column name key,
#     if, and only if, the column is a member of < agg_columns >.
#
#     The dictionary is passed directly to the DataFrame.agg() method to compute the summary
#     statistics. The < precision > value determines the number of decimal places to retain.
#
#     Parameters:
#         frame (pd.DataFrame): DataFrame of interest
#         agg_columns (list): List of columns to aggregate
#         agg_funcs (list): List of aggregation functions to compute
#         precision (int): Number of decimal places in which to round the summary stats
#
#     Returns:
#         pd.DataFrame: DataFrame of summary statistics for detraining passengers
#     """
#
#     pass  # TODO Implement me :)

# %%
import inspect, fra_amtrak.amtk_detrain as detrn

# Cek lokasi file-nya
print(inspect.getfile(detrn))
# Out:
# /home/jovyan/work/assignments/Course4/fra_amtrak/amtk_detrain.py

# %%
import fra_amtrak.amtk_detrain as detrn

def compute_sum_stats(frame, agg_columns, agg_funcs, precision=4):
    agg_dict = {
        col: agg_funcs
        for col in frame.columns
        if col in agg_columns
    }
    stats = frame.agg(agg_dict)
    return stats.round(precision)

def compute_sum_stats_by_group(frame, groups, agg_columns, agg_funcs, precision=4):
    agg_dict = {
        col: agg_funcs
        for col in frame.columns
        if col in agg_columns
    }
    stats = frame.groupby(groups).agg(agg_dict)
    return stats.round(precision)

detrn.compute_sum_stats = compute_sum_stats
detrn.compute_sum_stats_by_group = compute_sum_stats_by_group

print("✓ Patch berhasil!")
# Out:
# ✓ Patch berhasil!

# %%
svc_line_stats = detrn.get_sum_stats_by_group(
    network, COLS["svc_line"], AGG["columns"], AGG["funcs"]
)
svc_line_stats
# Out:
#          Service Line  Train Arrivals  Total Detraining Customers sum  \
# 0       Long Distance            9391                        10585139
# 1  Northeast Corridor           26353                        33736114
# 2     State Supported           32668                        34009681
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                        1127.1578                              400.0
# 1                        1280.1622                              379.0
# 2                        1041.0702                              260.0
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                       2542.7741                        5108705
# 1                       2526.2699                        7243328
# 2                       2307.4650                        7073116
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                        544.0001                             188.0
# 1                        274.8578                              52.0
# 2                        216.5151                              28.0
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                      1346.9626                                    0.4826
# 1                       684.2435                                    0.2147
# 2                       616.6383                                    0.2080
#
#    Late Detraining Customers Avg Min Late mean  \
# 0                                      88.3944
# 1                                      41.4993
# 2                                      41.3533
#
#    Total On Time Detraining Customers sum
# 0                                 5476434
# 1                                26492786
# 2                                26936565

# %% [markdown]
# ### 2.2 Services
#
# Each Amtrak service line consists of one or more services. A service is a named train (e.g., the
# [_California Zephyr_](https://www.amtrak.com/california-zephyr-train)) that operates on a specific
# route.
#
# Note that certain state-supported services
# (e.g., [Michigan service](https://www.amtrak.com/michigan-services-train)) represent a roll up of
# one or more named train sub services. The named trains that comprise these services are categorized
# as sub services and are excluded from the services column.

# %%
serv = network.loc[:, COLS["svc"]].unique()
serv.sort()

print(f"services (n={np.count_nonzero(serv)})")
serv
# Out:
# services (n=36)
# array(['Acela', 'Acela Express', 'Auto Train', 'Borealis',
#        'California Zephyr', 'Capitol Corridor', 'Capitol Ltd', 'Cardinal',
#        'Carolinian', 'Cascades', 'City Of New Orleans', 'Coast Starlight',
#        'Crescent', 'Downeaster', 'Empire', 'Empire Builder',
#        'Heartland Flyer', 'Hiawatha', 'Illinois', 'Keystone',
#        'Lake Shore Ltd', 'Lincoln / Missouri', 'Michigan', 'Missouri',
#        'Northeast Regional', 'Pacific Surfliner', 'Palmetto',
#        'Pennsylvanian', 'Piedmont', 'San Joaquins', 'Silver Meteor',
#        'Silver Star', 'Southwest Chief', 'Sunset Ltd', 'Texas Eagle',
#        'Vermonter'], dtype=object)

# %% [markdown]
# Service-level summary statistics cover all available fiscal years and quarters and are derived by
# aggregating metrics across each service.

# %%
svc_stats = detrn.get_sum_stats_by_group(network, COLS["svc"], AGG["columns"], AGG["funcs"])
svc_stats
# Out:
#                 Service  Train Arrivals  Total Detraining Customers sum  \
# 0                 Acela            2902                         4619992
# 1         Acela Express            2453                         3310356
# 2            Auto Train              22                          769068
# 3              Borealis              24                           26076
# 4     California Zephyr             924                          879399
# 5      Capitol Corridor            6330                         2344876
# 6           Capitol Ltd             330                          410704
# 7              Cardinal             677                          231145
# 8            Carolinian             512                         1120174
# 9              Cascades             998                         1680195
# 10  City Of New Orleans             536                          570194
# 11      Coast Starlight             645                          963087
# 12             Crescent             772                          722596
# 13           Downeaster            2624                         1466842
# 14               Empire            2889                         4922793
# 15       Empire Builder            1240                          949081
# 16      Heartland Flyer             143                          203124
# 17             Hiawatha             719                         1686218
# 18             Illinois            1517                         2309894
# 19             Keystone            6480                         5613036
# 20       Lake Shore Ltd             516                          931514
# 21   Lincoln / Missouri             342                          526633
# 22             Michigan            1079                         1768527
# 23             Missouri             268                          220544
# 24   Northeast Regional           20998                        25805766
# 25    Pacific Surfliner            4448                         5040187
# 26             Palmetto             487                          864402
# 27        Pennsylvanian             353                          743678
# 28             Piedmont             616                          797021
# 29         San Joaquins            1954                         2369993
# 30        Silver Meteor             574                          582976
# 31          Silver Star             742                         1076516
# 32      Southwest Chief             847                          667355
# 33           Sunset Ltd             463                          232582
# 34          Texas Eagle             616                          734520
# 35            Vermonter            1372                         1169870
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                         1592.0028                              513.5
# 1                         1349.5132                              377.0
# 2                        34957.6364                            33955.0
# 3                         1086.5000                              315.0
# 4                          951.7305                              296.5
# 5                          370.4385                              152.0
# 6                         1244.5576                              412.0
# 7                          341.4254                              132.0
# 8                         2187.8398                             1148.5
# 9                         1683.5621                              518.5
# 10                        1063.7948                              212.5
# 11                        1493.1581                              763.0
# 12                         936.0052                              413.0
# 13                         559.0099                              204.5
# 14                        1703.9782                              355.0
# 15                         765.3879                              274.0
# 16                        1420.4476                              291.0
# 17                        2345.2267                              432.0
# 18                        1522.6724                              313.0
# 19                         866.2093                              113.0
# 20                        1805.2597                              939.0
# 21                        1539.8626                              443.5
# 22                        1639.0426                              431.0
# 23                         822.9254                              307.5
# 24                        1228.9630                              364.0
# 25                        1133.1356                              478.5
# 26                        1774.9528                              903.0
# 27                        2106.7365                              629.0
# 28                        1293.8653                              471.0
# 29                        1212.8930                              584.5
# 30                        1015.6376                              554.0
# 31                        1450.8302                              799.5
# 32                         787.9044                              289.0
# 33                         502.3369                              174.0
# 34                        1192.4026                              331.0
# 35                         852.6749                              245.0
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                        2664.8921                         892373
# 1                        2404.6604                         576649
# 2                        5709.5216                         388045
# 3                        1998.4487                          13948
# 4                        1832.0447                         580584
# 5                         596.5200                         326186
# 6                        2515.8664                         188242
# 7                         613.9132                         107414
# 8                        2713.9962                         447639
# 9                        3059.3645                         686792
# 10                       2503.7947                         159831
# 11                       2148.3820                         428788
# 12                       1441.8226                         312884
# 13                       1211.6755                         275694
# 14                       3605.6108                         913867
# 15                       1555.9144                         459530
# 16                       2572.4566                          71379
# 17                       3842.2835                         184315
# 18                       3186.4862                         588798
# 19                       2200.5941                         361254
# 20                       2954.2611                         303362
# 21                       2671.9766                         233799
# 22                       3421.0704                         553760
# 23                       1210.4898                          66153
# 24                       2517.2658                        5774306
# 25                       1976.3956                         932657
# 26                       2455.8909                         279191
# 27                       3613.3614                         203640
# 28                       1738.8196                         224017
# 29                       1812.1234                         693228
# 30                       1357.8263                         298401
# 31                       1793.7612                         676760
# 32                       1825.1256                         453373
# 33                        808.2190                         147383
# 34                       2194.4798                         324917
# 35                       1798.3287                         295990
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                         307.5028                              75.0
# 1                         235.0791                              48.0
# 2                       17638.4091                           18247.5
# 3                         581.1667                             151.5
# 4                         628.3377                             180.0
# 5                          51.5302                              14.0
# 6                         570.4303                             174.0
# 7                         158.6617                              52.0
# 8                         874.2949                             449.0
# 9                         688.1683                             172.0
# 10                        298.1922                              95.5
# 11                        664.7876                             343.0
# 12                        405.2902                             171.5
# 13                        105.0663                              16.0
# 14                        316.3264                              47.0
# 15                        370.5887                             142.0
# 16                        499.1538                             121.0
# 17                        256.3491                              25.0
# 18                        388.1332                              71.0
# 19                         55.7491                               2.0
# 20                        587.9109                             308.5
# 21                        683.6228                             204.5
# 22                        513.2159                             136.0
# 23                        246.8396                              85.0
# 24                        274.9931                              50.0
# 25                        209.6801                              58.0
# 26                        573.2875                             265.0
# 27                        576.8839                             178.0
# 28                        363.6640                             114.0
# 29                        354.7738                             132.0
# 30                        519.8624                             285.0
# 31                        912.0755                             471.0
# 32                        535.2692                             176.0
# 33                        318.3218                             123.0
# 34                        527.4627                             153.0
# 35                        215.7362                              46.0
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                        587.7170                                    0.1932
# 1                        501.3870                                    0.1742
# 2                       7461.7180                                    0.5046
# 3                       1308.8852                                    0.5349
# 4                       1281.2414                                    0.6602
# 5                        110.6663                                    0.1391
# 6                       1413.6061                                    0.4583
# 7                        293.5920                                    0.4647
# 8                       1276.1080                                    0.3996
# 9                       1430.2456                                    0.4088
# 10                       605.9606                                    0.2803
# 11                      1060.4419                                    0.4452
# 12                       709.4344                                    0.4330
# 13                       330.7455                                    0.1880
# 14                       776.6600                                    0.1856
# 15                       829.4342                                    0.4842
# 16                       909.3809                                    0.3514
# 17                       546.3457                                    0.1093
# 18                       859.0212                                    0.2549
# 19                       193.9400                                    0.0644
# 20                      1129.6266                                    0.3257
# 21                      1152.9999                                    0.4440
# 22                      1132.6699                                    0.3131
# 23                       402.1131                                    0.3000
# 24                       714.2707                                    0.2238
# 25                       445.2761                                    0.1850
# 26                       855.4357                                    0.3230
# 27                      1128.7016                                    0.2738
# 28                       608.6659                                    0.2811
# 29                       579.5916                                    0.2925
# 30                       750.6544                                    0.5119
# 31                      1240.3593                                    0.6287
# 32                      1308.6266                                    0.6794
# 33                       535.9824                                    0.6337
# 34                      1037.3537                                    0.4424
# 35                       569.3841                                    0.2530
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       32.6096
# 1                                       30.6143
# 2                                      103.4091
# 3                                       40.6667
# 4                                      129.7636
# 5                                       38.1251
# 6                                       63.0424
# 7                                       70.2027
# 8                                       49.1932
# 9                                       42.1682
# 10                                      71.5010
# 11                                      79.9198
# 12                                      76.5020
# 13                                      39.0901
# 14                                      42.3543
# 15                                     118.3833
# 16                                      39.6613
# 17                                      39.2192
# 18                                      43.7766
# 19                                      39.4974
# 20                                      62.9435
# 21                                      49.8209
# 22                                      49.1500
# 23                                      46.9187
# 24                                      43.9998
# 25                                      42.6322
# 26                                      50.5077
# 27                                      40.6609
# 28                                      41.8824
# 29                                      40.7360
# 30                                      75.5129
# 31                                      78.1939
# 32                                     102.0210
# 33                                     105.5522
# 34                                      85.5205
# 35                                      44.3462
#
#     Total On Time Detraining Customers sum
# 0                                  3727619
# 1                                  2733707
# 2                                   381023
# 3                                    12128
# 4                                   298815
# 5                                  2018690
# 6                                   222462
# 7                                   123731
# 8                                   672535
# 9                                   993403
# 10                                  410363
# 11                                  534299
# 12                                  409712
# 13                                 1191148
# 14                                 4008926
# 15                                  489551
# 16                                  131745
# 17                                 1501903
# 18                                 1721096
# 19                                 5251782
# 20                                  628152
# 21                                  292834
# 22                                 1214767
# 23                                  154391
# 24                                20031460
# 25                                 4107530
# 26                                  585211
# 27                                  540038
# 28                                  573004
# 29                                 1676765
# 30                                  284575
# 31                                  399756
# 32                                  213982
# 33                                   85199
# 34                                  409603
# 35                                  873880

# %% [markdown]
# ### 2.3 Sub services
#
# The Amtrak sub service category is used to group named trains that operate as part of a service such
# as the [Illinois](https://www.amtrak.com/illinois-services-train) or
# [Michigan](https://www.amtrak.com/michigan-services-train) services (e.g., _Blue Water_,
# _Carl Sandburg_, _Illinois Zephyr_, _Pere Marquette_, _Saluki_, and _Wolverine_). Note that
# service-level named trains (e.g., _Acela_) are also included in the sub service category.

# %%
sub_serv = network.loc[:, COLS["sub_svc"]].unique()
sub_serv.sort()

print(f"subservices (n={np.count_nonzero(sub_serv)})")
sub_serv
# Out:
# subservices (n=48)
# array(['Acela', 'Acela Express', 'Adirondack', 'Auto Train',
#        'Berkshire Flyer', 'Blue Water', 'Borealis', 'California Zephyr',
#        'Capitol Corridor', 'Capitol Ltd', 'Cardinal',
#        'Carl Sandburg / Illinois Zephyr', 'Carolinian', 'Cascades',
#        'City Of New Orleans', 'Coast Starlight', 'Crescent', 'Downeaster',
#        'Empire Builder', 'Ethan Allen Express', 'Heartland Flyer',
#        'Hiawatha', 'Illini / Saluki', 'Keystone', 'Lake Shore Ltd',
#        'Lincoln / Missouri', 'Lincoln Service', 'Maple Leaf', 'Missouri',
#        'New York - Albany', 'New York - Niagara Falls',
#        'On Spine Northeast Regional', 'Pacific Surfliner', 'Palmetto',
#        'Pennsylvanian', 'Pere Marquette', 'Piedmont',
#        'Richmond / Newport News / Norfolk', 'Roanoke', 'San Joaquins',
#        'Silver Meteor', 'Silver Star', 'Southwest Chief',
#        'Springfield Shuttles', 'Sunset Ltd', 'Texas Eagle', 'Vermonter',
#        'Wolverine'], dtype=object)

# %% [markdown]
# Sub service-level summary statistics cover all available fiscal years and quarters and are derived
# by aggregating metrics across each sub service.

# %%
sub_svc_stats = detrn.get_sum_stats_by_group(network, COLS["sub_svc"], AGG["columns"], AGG["funcs"])
sub_svc_stats
# Out:
#                           Sub Service  Train Arrivals  \
# 0                               Acela            2902
# 1                       Acela Express            2453
# 2                          Adirondack             189
# 3                          Auto Train              22
# 4                     Berkshire Flyer              83
# 5                          Blue Water             220
# 6                            Borealis              24
# 7                   California Zephyr             924
# 8                    Capitol Corridor            6330
# 9                         Capitol Ltd             330
# 10                           Cardinal             677
# 11    Carl Sandburg / Illinois Zephyr             431
# 12                         Carolinian             512
# 13                           Cascades             998
# 14                City Of New Orleans             536
# 15                    Coast Starlight             645
# 16                           Crescent             772
# 17                         Downeaster            2624
# 18                     Empire Builder            1240
# 19                Ethan Allen Express             391
# 20                    Heartland Flyer             143
# 21                           Hiawatha             719
# 22                    Illini / Saluki             400
# 23                           Keystone            6480
# 24                     Lake Shore Ltd             516
# 25                 Lincoln / Missouri             342
# 26                    Lincoln Service             686
# 27                         Maple Leaf             363
# 28                           Missouri             268
# 29                  New York - Albany            1222
# 30           New York - Niagara Falls             641
# 31        On Spine Northeast Regional            9459
# 32                  Pacific Surfliner            4448
# 33                           Palmetto             487
# 34                      Pennsylvanian             353
# 35                     Pere Marquette              88
# 36                           Piedmont             616
# 37  Richmond / Newport News / Norfolk            6734
# 38                            Roanoke            1791
# 39                       San Joaquins            1954
# 40                      Silver Meteor             574
# 41                        Silver Star             742
# 42                    Southwest Chief             847
# 43               Springfield Shuttles            3014
# 44                         Sunset Ltd             463
# 45                        Texas Eagle             616
# 46                          Vermonter            1372
# 47                          Wolverine             771
#
#     Total Detraining Customers sum  Total Detraining Customers mean  \
# 0                          4619992                        1592.0028
# 1                          3310356                        1349.5132
# 2                           198905                        1052.4074
# 3                           769068                       34957.6364
# 4                            18308                         220.5783
# 5                           436721                        1985.0955
# 6                            26076                        1086.5000
# 7                           879399                         951.7305
# 8                          2344876                         370.4385
# 9                           410704                        1244.5576
# 10                          231145                         341.4254
# 11                          382231                         886.8469
# 12                         1120174                        2187.8398
# 13                         1680195                        1683.5621
# 14                          570194                        1063.7948
# 15                          963087                        1493.1581
# 16                          722596                         936.0052
# 17                         1466842                         559.0099
# 18                          949081                         765.3879
# 19                          514590                        1316.0870
# 20                          203124                        1420.4476
# 21                         1686218                        2345.2267
# 22                          709807                        1774.5175
# 23                         5613036                         866.2093
# 24                          931514                        1805.2597
# 25                          526633                        1539.8626
# 26                         1217856                        1775.3003
# 27                          651779                        1795.5344
# 28                          220544                         822.9254
# 29                         2302542                        1884.2406
# 30                         1236669                        1929.2808
# 31                        12772697                        1350.3221
# 32                         5040187                        1133.1356
# 33                          864402                        1774.9528
# 34                          743678                        2106.7365
# 35                          238206                        2706.8864
# 36                          797021                        1293.8653
# 37                         9286572                        1379.0573
# 38                         2823985                        1576.7644
# 39                         2369993                        1212.8930
# 40                          582976                        1015.6376
# 41                         1076516                        1450.8302
# 42                          667355                         787.9044
# 43                          922512                         306.0756
# 44                          232582                         502.3369
# 45                          734520                        1192.4026
# 46                         1169870                         852.6749
# 47                         1093600                        1418.4176
#
#     Total Detraining Customers median  Total Detraining Customers std  \
# 0                               513.5                       2664.8921
# 1                               377.0                       2404.6604
# 2                               155.0                       2482.1179
# 3                             33955.0                       5709.5216
# 4                                22.0                        532.6021
# 5                               527.0                       4256.8445
# 6                               315.0                       1998.4487
# 7                               296.5                       1832.0447
# 8                               152.0                        596.5200
# 9                               412.0                       2515.8664
# 10                              132.0                        613.9132
# 11                              243.0                       1558.5837
# 12                             1148.5                       2713.9962
# 13                              518.5                       3059.3645
# 14                              212.5                       2503.7947
# 15                              763.0                       2148.3820
# 16                              413.0                       1441.8226
# 17                              204.5                       1211.6755
# 18                              274.0                       1555.9144
# 19                              322.0                       3274.5708
# 20                              291.0                       2572.4566
# 21                              432.0                       3842.2835
# 22                              293.5                       4130.3734
# 23                              113.0                       2200.5941
# 24                              939.0                       2954.2611
# 25                              443.5                       2671.9766
# 26                              376.0                       3264.0766
# 27                              872.0                       3323.0553
# 28                              307.5                       1210.4898
# 29                              204.5                       3710.2047
# 30                              642.0                       4141.9269
# 31                              410.0                       2707.8113
# 32                              478.5                       1976.3956
# 33                              903.0                       2455.8909
# 34                              629.0                       3613.3614
# 35                              761.0                       3651.0593
# 36                              471.0                       1738.8196
# 37                              489.0                       2582.8316
# 38                              624.0                       2756.8977
# 39                              584.5                       1812.1234
# 40                              554.0                       1357.8263
# 41                              799.5                       1793.7612
# 42                              289.0                       1825.1256
# 43                               54.0                        836.0882
# 44                              174.0                        808.2190
# 45                              331.0                       2194.4798
# 46                              245.0                       1798.3287
# 47                              402.0                       3084.1497
#
#     Late Detraining Customers sum  Late Detraining Customers mean  \
# 0                          892373                        307.5028
# 1                          576649                        235.0791
# 2                           54967                        290.8307
# 3                          388045                      17638.4091
# 4                            8778                        105.7590
# 5                          139527                        634.2136
# 6                           13948                        581.1667
# 7                          580584                        628.3377
# 8                          326186                         51.5302
# 9                          188242                        570.4303
# 10                         107414                        158.6617
# 11                          72063                        167.1995
# 12                         447639                        874.2949
# 13                         686792                        688.1683
# 14                         159831                        298.1922
# 15                         428788                        664.7876
# 16                         312884                        405.2902
# 17                         275694                        105.0663
# 18                         459530                        370.5887
# 19                         118953                        304.2276
# 20                          71379                        499.1538
# 21                         184315                        256.3491
# 22                         203722                        509.3050
# 23                         361254                         55.7491
# 24                         303362                        587.9109
# 25                         233799                        683.6228
# 26                         313013                        456.2872
# 27                         155520                        428.4298
# 28                          66153                        246.8396
# 29                         284516                        232.8282
# 30                         291133                        454.1856
# 31                        2183619                        230.8509
# 32                         932657                        209.6801
# 33                         279191                        573.2875
# 34                         203640                        576.8839
# 35                          43311                        492.1705
# 36                         224017                        363.6640
# 37                        2619636                        389.0163
# 38                         848260                        473.6237
# 39                         693228                        354.7738
# 40                         298401                        519.8624
# 41                         676760                        912.0755
# 42                         453373                        535.2692
# 43                         122791                         40.7402
# 44                         147383                        318.3218
# 45                         324917                        527.4627
# 46                         295990                        215.7362
# 47                         370922                        481.0921
#
#     Late Detraining Customers median  Late Detraining Customers std  \
# 0                               75.0                       587.7170
# 1                               48.0                       501.3870
# 2                               42.0                       966.4512
# 3                            18247.5                      7461.7180
# 4                                9.0                       398.0666
# 5                              150.0                      1592.8122
# 6                              151.5                      1308.8852
# 7                              180.0                      1281.2414
# 8                               14.0                       110.6663
# 9                              174.0                      1413.6061
# 10                              52.0                       293.5920
# 11                              40.0                       284.4213
# 12                             449.0                      1276.1080
# 13                             172.0                      1430.2456
# 14                              95.5                       605.9606
# 15                             343.0                      1060.4419
# 16                             171.5                       709.4344
# 17                              16.0                       330.7455
# 18                             142.0                       829.4342
# 19                              56.0                      1043.2246
# 20                             121.0                       909.3809
# 21                              25.0                       546.3457
# 22                              71.0                      1229.3682
# 23                               2.0                       193.9400
# 24                             308.5                      1129.6266
# 25                             204.5                      1152.9999
# 26                              88.0                       811.2110
# 27                             163.0                       898.5537
# 28                              85.0                       402.1131
# 29                              13.0                       577.4255
# 30                             115.0                       791.0639
# 31                              45.0                       595.0997
# 32                              58.0                       445.2761
# 33                             265.0                       855.4357
# 34                             178.0                      1128.7016
# 35                             169.0                       651.5801
# 36                             114.0                       608.6659
# 37                              96.0                       864.1126
# 38                             120.0                      1043.5519
# 39                             132.0                       579.5916
# 40                             285.0                       750.6544
# 41                             471.0                      1240.3593
# 42                             176.0                      1308.6266
# 43                               3.0                       120.8422
# 44                             123.0                       535.9824
# 45                             153.0                      1037.3537
# 46                              46.0                       569.3841
# 47                             135.0                      1010.5961
#
#     Late to Total Detraining Customers Ratio  \
# 0                                     0.1932
# 1                                     0.1742
# 2                                     0.2763
# 3                                     0.5046
# 4                                     0.4795
# 5                                     0.3195
# 6                                     0.5349
# 7                                     0.6602
# 8                                     0.1391
# 9                                     0.4583
# 10                                    0.4647
# 11                                    0.1885
# 12                                    0.3996
# 13                                    0.4088
# 14                                    0.2803
# 15                                    0.4452
# 16                                    0.4330
# 17                                    0.1880
# 18                                    0.4842
# 19                                    0.2312
# 20                                    0.3514
# 21                                    0.1093
# 22                                    0.2870
# 23                                    0.0644
# 24                                    0.3257
# 25                                    0.4440
# 26                                    0.2570
# 27                                    0.2386
# 28                                    0.3000
# 29                                    0.1236
# 30                                    0.2354
# 31                                    0.1710
# 32                                    0.1850
# 33                                    0.3230
# 34                                    0.2738
# 35                                    0.1818
# 36                                    0.2811
# 37                                    0.2821
# 38                                    0.3004
# 39                                    0.2925
# 40                                    0.5119
# 41                                    0.6287
# 42                                    0.6794
# 43                                    0.1331
# 44                                    0.6337
# 45                                    0.4424
# 46                                    0.2530
# 47                                    0.3392
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       32.6096
# 1                                       30.6143
# 2                                       45.7814
# 3                                      103.4091
# 4                                       57.5385
# 5                                       51.7512
# 6                                       40.6667
# 7                                      129.7636
# 8                                       38.1251
# 9                                       63.0424
# 10                                      70.2027
# 11                                      39.5839
# 12                                      49.1932
# 13                                      42.1682
# 14                                      71.5010
# 15                                      79.9198
# 16                                      76.5020
# 17                                      39.0901
# 18                                     118.3833
# 19                                      42.7734
# 20                                      39.6613
# 21                                      39.2192
# 22                                      45.7801
# 23                                      39.4974
# 24                                      62.9435
# 25                                      49.8209
# 26                                      45.2147
# 27                                      46.6374
# 28                                      46.9187
# 29                                      38.9502
# 30                                      42.3416
# 31                                      44.6541
# 32                                      42.6322
# 33                                      50.5077
# 34                                      40.6609
# 35                                      40.7361
# 36                                      41.8824
# 37                                      45.0434
# 38                                      45.4981
# 39                                      40.7360
# 40                                      75.5129
# 41                                      78.1939
# 42                                     102.0210
# 43                                      36.9551
# 44                                     105.5522
# 45                                      85.5205
# 46                                      44.3462
# 47                                      49.2532
#
#     Total On Time Detraining Customers sum
# 0                                  3727619
# 1                                  2733707
# 2                                   143938
# 3                                   381023
# 4                                     9530
# 5                                   297194
# 6                                    12128
# 7                                   298815
# 8                                  2018690
# 9                                   222462
# 10                                  123731
# 11                                  310168
# 12                                  672535
# 13                                  993403
# 14                                  410363
# 15                                  534299
# 16                                  409712
# 17                                 1191148
# 18                                  489551
# 19                                  395637
# 20                                  131745
# 21                                 1501903
# 22                                  506085
# 23                                 5251782
# 24                                  628152
# 25                                  292834
# 26                                  904843
# 27                                  496259
# 28                                  154391
# 29                                 2018026
# 30                                  945536
# 31                                10589078
# 32                                 4107530
# 33                                  585211
# 34                                  540038
# 35                                  194895
# 36                                  573004
# 37                                 6666936
# 38                                 1975725
# 39                                 1676765
# 40                                  284575
# 41                                  399756
# 42                                  213982
# 43                                  799721
# 44                                   85199
# 45                                  409603
# 46                                  873880
# 47                                  722678

# %% [markdown]
# ### 2.4 Stations
#
# Each `network` row represents Amtrak station arrival metrics, aggregated quarterly, for a given
# train (e.g., _Wolverine_ Train 350 arrivals at [Ann Arbor](https://www.amtrak.com/stations/arb)
# station (ARB) during Q3 2024).
#
# Station-level summary statistics will be explored in a separate notebook.

# %%
stn_count = network.loc[:, COLS["station_code"]].nunique()
stn_count
# Out:
# 533

# %% [markdown]
# ### 2.5 Regions and divisions
#
# The Amtrak stations in `network` can be grouped by region and/or division. These geographical
# groupings are based on US Census Bureau
# [categories](https://www.census.gov/programs-surveys/economic-census/guidance-geographies/levels.html)
# rather than FRA or Amtrak designations.
#
# Group by stations by region. Ensure that regional station counts are consistent with the total station count.
#
# #### 2.5.1 Regions [1 pt]
#
#  The `DataFrame` named `region_stn_counts` provides stations counts grouped by region.

# %%
region_stn_counts = (
    network.groupby(COLS["region"])[COLS["station_code"]]
    .nunique()
    .reset_index()
    .sort_values(by=COLS["region"])
)
region_stn_counts
# Out:
#       Region  Arrival Station Code
# 0    Midwest                   121
# 1  Northeast                   115
# 2      South                   149
# 3       West                   146

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 2.5.2 Divisions [1 pt]
#
# The `DataFrame` named `division_stn_counts` provides station counts grouped by region and divison.

# %%
div_stn_counts = (
    network.groupby([COLS["region"], COLS["division"]])[COLS["station_code"]]
    .nunique()
    .reset_index()
    .sort_values(by=[COLS["region"], COLS["division"]])
)
div_stn_counts
# Out:
#        Region            Division  Arrival Station Code
# 0     Midwest  East North Central                    78
# 1     Midwest  West North Central                    43
# 2   Northeast      Eastern Canada                     4
# 3   Northeast     Middle Atlantic                    57
# 4   Northeast         New England                    54
# 5       South  East South Central                    19
# 6       South      South Atlantic                    93
# 7       South  West South Central                    37
# 8        West            Mountain                    44
# 9        West             Pacific                   101
# 10       West      Western Canada                     1

# %%
# hidden tests are within this cell

# %% [markdown]
# ## 3.0 On-time performance metrics (entire period)
#
# Amtrak station performance data is a compilation of quarterly metrics that focus on late
# detraining passengers. Detraining assengers are considered on-time if they arrive at their
# destination no later than fifteen (`15`) minutes after their scheduled arrival time. All other
# detraining passengers are considered late.

# %% [markdown]
# ### 3.1 Mean late arrival times summary statistics [1 pt]
#
# Review the central tendency, dispersion, and shape of mean late arrival times across the
# network. Calling the custom function named `frm.describe_numeric_column()` will return an
# "enriched" dictionary of summary statistics.

# %%
# Cell 3.1 — jalankan ini dulu
network_avg_mm_late = network[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

network_avg_mm_late_describe = frm.describe_numeric_column(network_avg_mm_late)
network_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(57373),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(48.78976173461384),
#   'median': 39.0,
#   'mode': np.float64(30.0)},
#  'position': {'min': np.float64(2.0),
#   '25%': np.float64(29.0),
#   '50%': np.float64(39.0),
#   '75%': np.float64(56.0),
#   'max': np.float64(866.0)},
#  'spread': {'variance': 1334.5036970306662,
#   'std': 36.53085951672457,
#   'range': 864.0,
#   'iqr': np.float64(27.0)},
#  'shape': {'skewness': np.float64(4.902910630653301),
#   'kurtosis': np.float64(49.51440917305096)}}

# %%
# hidden tests are within this cell

# %% [markdown]
# The skewness and kurtosis values returned suggest that the distribution of mean late arrival times
# of Amtrak trains are positively skewed and features a sharper peak and heavier right tail than a
# normal distribution. Let's confirm this visually by generating a histogram.

# %% [markdown]
# ### 3.2 Visualize distribution of mean late arrival times
#
# Visualize mean late arrival times for the entire period. The data is binned prior to plotting.
#
# #### 3.2.1 Create the chart data

# %%
import inspect
import fra_amtrak.amtk_frame as frm
print(inspect.getsource(frm.describe_numeric_column))
# Out:
# def describe_numeric_column(column):
#     try:
#         if np.issubdtype(column.dtype, np.number):
#             if column.isnull().any():
#                 warnings.warn(
#                     "Column contains missing values. Interquartile range (IQR) will not be computed.",
#                     UserWarning,
#                 )
#
#             min_ = column.min()
#             max_ = column.max()
#
#             return {
#                 "type": column.__class__,
#                 "name": column.name,
#                 "values": {
#                     "non_null": column.count(),
#                     "missing": column.isna().sum(),
#                     "dtype": column.dtype,
#                 },
#                 "center": {
#                     "mean": column.mean(),
#                     "median": column.median(),
#                     "mode": column.mode()[0] if not column.mode().empty else None,
#                 },
#                 "position": {
#                     "min": np.float64(min_),   # ← numpy scalar agar .astype() bisa dipanggil
#                     "25%": np.float64(column.quantile(0.25)),
#                     "50%": np.float64(column.quantile()),
#                     "75%": np.float64(column.quantile(0.75)),
#                     "max": np.float64(max_),   # ← ini yang penting
#                 },
#                 "spread": {
#                     "variance": column.var(),
#                     "std": column.std(),
#                     "range": max_ - min_,
#                     "iqr": stats.iqr(column),
#                 },
#                 "shape": {
#                     "skewness": column.skew(),
#                     "kurtosis": column.kurt(),
#                 },
#             }
#         else:
#             warnings.warn("Provided column is not numeric.", UserWarning)
#             return None
#     except (AttributeError, TypeError, ValueError) as e:
#         warnings.warn(f"{e}", UserWarning)
#         return None

# %%
import numpy as np
import warnings
import fra_amtrak.amtk_frame as frm

def describe_numeric_column(column):
    try:
        if np.issubdtype(column.dtype, np.number):
            if column.isnull().any():
                warnings.warn(
                    "Column contains missing values. Interquartile range (IQR) will not be computed.",
                    UserWarning,
                )

            min_ = column.min()
            max_ = column.max()

            return {
                "type": column.__class__,
                "name": column.name,
                "values": {
                    "non_null": column.count(),
                    "missing": column.isna().sum(),
                    "dtype": column.dtype,
                },
                "center": {
                    "mean": column.mean(),
                    "median": column.median(),
                    "mode": column.mode()[0] if not column.mode().empty else None,
                },
                "position": {
                    "min": np.float64(min_),   # ← numpy scalar agar .astype() bisa dipanggil
                    "25%": np.float64(column.quantile(0.25)),
                    "50%": np.float64(column.quantile()),
                    "75%": np.float64(column.quantile(0.75)),
                    "max": np.float64(max_),   # ← ini yang penting
                },
                "spread": {
                    "variance": column.var(),
                    "std": column.std(),
                    "range": max_ - min_,
                    "iqr": stats.iqr(column),
                },
                "shape": {
                    "skewness": column.skew(),
                    "kurtosis": column.kurt(),
                },
            }
        else:
            warnings.warn("Provided column is not numeric.", UserWarning)
            return None
    except (AttributeError, TypeError, ValueError) as e:
        warnings.warn(f"{e}", UserWarning)
        return None

frm.describe_numeric_column = describe_numeric_column
print("✓ describe_numeric_column patch berhasil!")
# Out:
# ✓ describe_numeric_column patch berhasil!

# %%
# Convert to DataFrame
network_avg_mm_late = network_avg_mm_late.to_frame(name=COLS["avg_mm_late"])

# Get mean and standard deviation
mu = network_avg_mm_late_describe["center"]["mean"]
sigma = network_avg_mm_late_describe["spread"]["std"]

# Get max value (for x-axis ticks); pad max value for chart display
max_val = network_avg_mm_late_describe["position"]["max"].astype(int)
max_val_ceil = (np.ceil(max_val / 10) * 10).astype(float)

# Create bins
network_avg_mm_late, bins, num_bins, bin_width = frm.create_bins(
    network_avg_mm_late, COLS["avg_mm_late"], 15
)

# Bin the data
chrt_data = frm.bin_data(network_avg_mm_late, COLS["avg_mm_late"], bins)
# chart_data

# %% [markdown]
# #### 3.2.2 Generate the histogram

# %%
# Total train arrivals
network_trn_arrivals = network.shape[0]

# Detraining totals
network_detrn = network[COLS["total_detrn"]].sum()
network_detrn_late = network[COLS["late_detrn"]].sum()
network_detrn_on_time = network_detrn - network_detrn_late

print(
    f"Train Arrivals: {network_trn_arrivals}",
    f"Total Detraining Customers: {network_detrn}",
    f"Late Detraining Customers: {network_detrn_late}",
    f"On-Time Detraining Customers: {network_detrn_on_time}",
    sep="\n",
)

# Compute summary statistics
network_stats = detrn.get_sum_stats(network, AGG["columns"], AGG["funcs"])
network_stats
# Out:
# Train Arrivals: 68412
# Total Detraining Customers: 78330934
# Late Detraining Customers: 19425149
# On-Time Detraining Customers: 58905785
#    Train Arrivals  Total Detraining Customers sum  \
# 0           68412                      78330934.0
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                        1144.9882                              323.0
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                       2429.1023                     19425149.0
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                        283.9436                              50.0
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                       788.9444                                     0.248
#
#   Late Detraining Customers Avg Min Late mean  \
# 0                                        None
#
#    Total On Time Detraining Customers sum
# 0                              58905785.0

# %%
title = chrt.format_title(network_stats, "Amtrak Network Late Detraining Passengers")
chart = (
    hst_bld.HistogramBuilder(hst.HistogramChart(frame=chrt_data, title=title))
    .x(
        axis_tick_count=max_val_ceil,
        axis_values=np.arange(0.0, max_val_ceil + 15, 5).tolist(),  # store float values
        bin_max_bins=num_bins,
        bin_step=bin_width,
        scale_domain=[0.0, max_val_ceil],
    )
    .mu_rule(mu=mu)
    .sigma_rules(sigma=sigma, n=2)
    .build()
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## 4.0 On-time performance metrics (by fiscal year and quarter)
#
# Compute OTP summary statistics per fiscal year and quarter. Add quarterly train arrival metrics to
# the `DataFrame` named `network_qtr_stats`.

# %%
# Get quarterly stats
network_qtr_stats = detrn.get_sum_stats_by_group(
    network,
    [COLS["year"], COLS["quarter"]],
    AGG["columns"],
    AGG["funcs"],
    network_trn_arrivals,
    network_detrn,
)
network_qtr_stats
# Out:
#     Fiscal Year  Fiscal Quarter  Train Arrivals  Train Arrival Ratio  \
# 0          2021               4            3860             0.056423
# 1          2022               1            5656             0.082676
# 2          2022               2            5484             0.080161
# 3          2022               3            5335             0.077983
# 4          2022               4            5530             0.080834
# 5          2023               1            5682             0.083056
# 6          2023               2            5819             0.085058
# 7          2023               3            6137             0.089706
# 8          2023               4            6112             0.089341
# 9          2024               1            6059             0.088566
# 10         2024               2            6519             0.095290
# 11         2024               3            6219             0.090905
#
#     Detraining Ratio  Total Detraining Customers sum  \
# 0           0.042569                         3334492
# 1           0.070222                         5500565
# 2           0.052795                         4135460
# 3           0.080138                         6277302
# 4           0.088057                         6897574
# 5           0.088201                         6908867
# 6           0.075116                         5883945
# 7           0.093320                         7309838
# 8           0.103940                         8141720
# 9           0.106022                         8304809
# 10          0.093053                         7288908
# 11          0.106567                         8347454
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                          863.8580                              232.0
# 1                          972.5186                              274.0
# 2                          754.0956                              195.0
# 3                         1176.6264                              326.0
# 4                         1247.3009                              352.0
# 5                         1215.9217                              347.5
# 6                         1011.1609                              280.0
# 7                         1191.1093                              339.0
# 8                         1332.0877                              391.5
# 9                         1370.6567                              435.0
# 10                        1118.1022                              323.0
# 11                        1342.2502                              402.0
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                        1830.2290                         560163
# 1                        2122.3845                        1323483
# 2                        1721.7037                         994549
# 3                        2514.7755                        1623780
# 4                        2612.6326                        2045867
# 5                        2574.4133                        1758247
# 6                        2150.7339                        1188089
# 7                        2524.0602                        1915619
# 8                        2739.8684                        2368441
# 9                        2742.9429                        1839525
# 10                       2298.7794                        1510763
# 11                       2710.8542                        2296623
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                         145.1199                              21.0
# 1                         233.9963                              41.0
# 2                         181.3547                              31.0
# 3                         304.3636                              48.0
# 4                         369.9579                              65.0
# 5                         309.4416                              62.0
# 6                         204.1741                              33.0
# 7                         312.1426                              58.0
# 8                         387.5067                              81.0
# 9                         303.6021                              66.0
# 10                        231.7477                              44.0
# 11                        369.2914                              72.0
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                        395.5343                                    0.1680
# 1                        749.2579                                    0.2406
# 2                        618.5795                                    0.2405
# 3                        946.0424                                    0.2587
# 4                        953.5369                                    0.2966
# 5                        830.6276                                    0.2545
# 6                        591.8177                                    0.2019
# 7                        810.8011                                    0.2621
# 8                        929.0555                                    0.2909
# 9                        711.0765                                    0.2215
# 10                       619.6241                                    0.2073
# 11                       957.9910                                    0.2751
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       40.8754
# 1                                       47.5030
# 2                                       51.7952
# 3                                       49.6261
# 4                                       48.4402
# 5                                       51.2844
# 6                                       56.9817
# 7                                       45.0473
# 8                                       50.2355
# 9                                       46.3932
# 10                                      47.7256
# 11                                      47.4861
#
#     Total On Time Detraining Customers sum
# 0                                  2774329
# 1                                  4177082
# 2                                  3140911
# 3                                  4653522
# 4                                  4851707
# 5                                  5150620
# 6                                  4695856
# 7                                  5394219
# 8                                  5773279
# 9                                  6465284
# 10                                 5778145
# 11                                 6050831

# %% [markdown]
# ### 4.1 Write to file [1 pt]
#
# Write `network_qtr_stats` to a CSV file named `stu-amtk-network_qtr_stats.csv`. Store the file in the
# `data/student` directory. Then compare it to the accompanying `fxt-amtk-network_qtr_stats.csv` file.
# It must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk-network_qtr_stats.csv")
network_qtr_stats.to_csv(filepath, index=False)

# %%
# hidden tests are within this cell

# %% [markdown]
# ## 5.0 Visualize detraining passengers (by fiscal year and quarter)
#
# Visualize Amtrak's detraining passengers, both on-time and late, across all years and quarters with
# a bar chart.

# %%
# Chart data and title
chrt_data = detrn.create_detrain_chart_frame(network_qtr_stats, CHRT_BAR["columns"])
title = chrt.format_title(network_stats, "Amtrak Network Late Detraining Passengers")

# Construct grouped bar chart
chart = bar_bld.GrpBarBuilder(bar.GrpBarChart(frame=chrt_data, title=title)).build()
chart.display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 6.0 Visualize distribution of mean late arrival times (by fiscal year and quarter)
#
# Visualizing mean late arrival times grouped by fiscal year and quarter may reveal interesting
# patterns.
#
# The data is flattened prior to creating a series of box plots. The fiscal year and quarter column
# values are combined (e.g., `< year >Q< quarter >`) by applying the function named
# `detrn.format_year_quarter()` to each row to create a new column named "Fiscal Year Quarter". A
# second column is also added to color code each quarter and its associated box plot.
#
# ### 6.1 Create the chart data [1 pt]

# %%
def format_year_quarter(row):
    # Cari kolom year dan quarter secara dinamis
    year_col = COLS["year"]
    quarter_col = COLS["quarter"]
    year = int(row[year_col])
    quarter = int(row[quarter_col])
    return f"{year}Q{quarter}"

detrn.format_year_quarter = format_year_quarter
print("✓ format_year_quarter patch berhasil!")
# Out:
# ✓ format_year_quarter patch berhasil!

# %%
cols = [COLS["year"], COLS["quarter"], COLS["late_detrn_avg_mm_late"]]

# Group by fiscal year and quarter and flatten
chrt_data = network.groupby(cols[:2])[cols].apply(lambda x: x).reset_index(drop=True)

# Add 'Fiscal Year Quarter' column
chrt_data[COLS["year_quarter"]] = chrt_data.apply(detrn.format_year_quarter, axis=1)


# Drop columns and reorder
chrt_data.drop([COLS["year"], COLS["quarter"]], axis=1, inplace=True)
chrt_data.insert(0, COLS["year_quarter"], chrt_data.pop(COLS["year_quarter"]))

# Add color column
colors = [COLORS["amtk_blue"], COLORS["amtk_red"]]
chrt_data.loc[:, "Color"] = chrt_data[COLS["year_quarter"]].apply(detrn.assign_color, colors=colors)
chrt_data.head()
# Out:
#   Fiscal Year Quarter  Late Detraining Customers Avg Min Late    Color
# 0              2021Q4                                   100.0  #00537e
# 1              2021Q4                                    25.0  #00537e
# 2              2021Q4                                    51.0  #00537e
# 3              2021Q4                                    78.0  #00537e
# 4              2021Q4                                    53.0  #00537e

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 6.2 Preaggregate the chart data
#
# Attempting to instantiate an instance of a Vega-Altair [`alt.Chart()`](https://altair-viz.github.io/user_guide/generated/toplevel/altair.Chart.html) class by passing to it a dataset comprising more than `5000` rows will trigger a `MaxRowsError`. You can disable the `MaxRows` check by calling `alt.data_transformers.disable_max_rows()` method. However, disabling the check may result in performance issues, including browser crashes.
#
# The preferred approach when [working with large datasets](https://altair-viz.github.io/user_guide/large_datasets.html#large-datasets) is to _preaggregate_ the data before generating a plot. This can be achieved "manually"&mdash;the approach adopted in this notebook&mdash;or by [installing](https://altair-viz.github.io/user_guide/large_datasets.html#installing-vegafusion[) and [enabling](https://altair-viz.github.io/user_guide/large_datasets.html#enabling-the-vegafusion-data-transformer) Altair's companion [vegafusion](https://vegafusion.io/) data transformer package.

# %%
# Compute aggregation statistics
cols = [COLS["year_quarter"], COLS["late_detrn_avg_mm_late"]]

# Pre-aggregate the data
chrt_data = frm.aggregate_data(chrt_data, cols)

# %% [markdown]
# ### 6.3 Generate the box plots

# %%
# Create chart title
title_text = "Amtrak Network Late Detraining Passengers"
title = chrt.format_title(network_stats, title_text)

chart = (
    bxp_bld.BoxPlotBuilder(bxp.BoxplotPreAggChart(frame=chrt_data, title=title))
    .boxplot_mark_properties(orient="horizontal")
    .y(axis_grid=False)
    .build()
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## 7.0 Distance traveled and late detraining passengers
#
# A number of factors influence the likelihood of late detraining passengers. Distance traveled is
# possibly one such factor. Does a linear relationship exist between a train's route miles and the
# late arrival times experienced by late detraining passengers?
#
# ### 7.1 Data preparation
#
# The first step involves preparing the data for the regression analysis.

# %%
lm_data = network[[COLS["route_miles"], COLS["late_detrn_avg_mm_late"]]].reset_index(drop=True)
lm_data.shape
# Out:
# (68412, 2)

# %% [markdown]
# ### 7.2 Linear regression [1 pt]
#
# The code below calculates a linear least-squares regression for two sets of measurements. The
# dependent variable is "Late Detraining Customers Avg Min Late". The independent variable is
# "Route Miles". The `result` object contains the regression attributes.

# %%
# YOUR CODE HERE
# Drop rows dengan missing values
lm_data_clean = lm_data.dropna()

# Hitung linear regression
# x = Route Miles (independen), y = Avg Min Late (dependen)
result = stats.linregress(
    lm_data_clean[COLS["route_miles"]],
    lm_data_clean[COLS["late_detrn_avg_mm_late"]],
)
result
# Out:
# LinregressResult(slope=np.float64(0.033865823231644165), intercept=np.float64(28.48236724388004), rvalue=np.float64(0.5048653697334845), pvalue=np.float64(0.0), stderr=np.float64(0.000241741003417831), intercept_stderr=np.float64(0.1958177028456057))

# %%
# hidden tests are within this cell

# %% [markdown]
# The linear regression analysis suggests that there is a moderate positive relationship between a train's route miles and mean late arrival times for late detraining passengers. The slope suggests that with every additional route mile traveled, the average minutes late for late detraining passengers increases by approximately `0.0338` minutes. The *R*² value indicates that around `25.5%` of the variability in the average minutes late can be explained by route miles, with the remaining variability due to other factors or random noise. The very small standard errors for both the slope and intercept coefficients suggest a high level of precision in these estimates.

# %% [markdown]
# ### 7.3 Predictions
#
# #### 7.3.1 Twenty-five mile intervals [1 pt]
#
# Create a new `DataFrame` named `route_mi_intervals` comprising a single column named "Route Miles"
# with values ranging from `0` to `2600` in increments of `25`.
#
# Then apply the function `detrn.predict_avg_min_late()` to each of the "Route Miles" values to
# generate predicted average late times for every twenty-five (`25`) miles of rail travel up to `2600`
# miles.
#
# For the starting zero (`0`) route mile mark, assign the predicted average late time to `0.0`
# minutes. Round each predicted value to two decimal places. Assign each predicted value to a new
# column named "Predicted Avg Min Late".

# %%
def predict_avg_min_late(result, route_miles):
    """Prediksi rata-rata menit terlambat berdasarkan route miles
    menggunakan hasil linear regression.
    
    Parameters:
        result: hasil dari scipy.stats.linregress
        route_miles (float): jarak rute dalam mil
    
    Returns:
        float: prediksi rata-rata menit terlambat
    """
    return result.slope * route_miles + result.intercept

detrn.predict_avg_min_late = predict_avg_min_late
print("✓ predict_avg_min_late patch berhasil!")
# Out:
# ✓ predict_avg_min_late patch berhasil!

# %%
# YOUR CODE HERE
# Buat DataFrame dengan Route Miles 0 sampai 2600, step 25
route_mi_intervals = pd.DataFrame({COLS["route_miles"]: np.arange(0, 2601, 25)})

# Prediksi avg min late; nilai 0 mil di-assign 0.0 langsung
route_mi_intervals[COLS["predict_avg_mm_late"]] = route_mi_intervals[COLS["route_miles"]].apply(
    lambda x: 0.0 if x == 0 else round(detrn.predict_avg_min_late(result, x), 2)
)
route_mi_intervals
# Out:
#      Route Miles  Predicted Avg Min Late
# 0              0                    0.00
# 1             25                   29.33
# 2             50                   30.18
# 3             75                   31.02
# 4            100                   31.87
# ..           ...                     ...
# 100         2500                  113.15
# 101         2525                  113.99
# 102         2550                  114.84
# 103         2575                  115.69
# 104         2600                  116.53
#
# [105 rows x 2 columns]

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 7.3.2 Named train route miles [1 pt]
#
# Create a `DataFrame` of predicted late times for named trains to combine with `route_mi_intervals`.
# Retrieve each named train (e.g. the sub service) and their associate route miles from `network` and
# store in two columns named "Sub Service" and "Route Miles". Assign the new `DataFrame` to a variable
# named `trn_route_mi`.
#
# Next, generate predictions for each row in `trn_route_mi`. Round the predictions to the second
# (`2nd`) decimal place. Assign the predictions to a new column named "Predicted Avg Min Late".
#
# Note that these predicted average late times are relevant only for late detraining passengers who
# travel the entire route.

# %%
# YOUR CODE HERE
# Ambil unique sub service dan route miles dari network
trn_route_mi = (
    network[[COLS["sub_svc"], COLS["route_miles"]]]
    .drop_duplicates()
    .reset_index(drop=True)
)

# Prediksi avg min late untuk setiap named train
trn_route_mi[COLS["predict_avg_mm_late"]] = trn_route_mi[COLS["route_miles"]].apply(
    lambda x: round(detrn.predict_avg_min_late(result, x), 2)
)
trn_route_mi
# Out:
#                           Sub Service  Route Miles  Predicted Avg Min Late
# 0                          Auto Train          914                   59.44
# 1                   California Zephyr         2408                  110.03
# 2                         Capitol Ltd          788                   55.17
# 3                            Cardinal         1140                   67.09
# 4                 City Of New Orleans          930                   59.98
# 5                     Coast Starlight         1388                   75.49
# 6                            Crescent         1367                   74.78
# 7                      Empire Builder         2560                  115.18
# 8                      Lake Shore Ltd         1255                   70.98
# 9                            Palmetto          885                   58.45
# 10                      Silver Meteor         1281                   71.86
# 11                        Silver Star         1592                   82.40
# 12                    Southwest Chief         2286                  105.90
# 13                         Sunset Ltd         1974                   95.33
# 14                        Texas Eagle         1257                   71.05
# 15                              Acela          457                   43.96
# 16        On Spine Northeast Regional          519                   46.06
# 17  Richmond / Newport News / Norfolk          789                   55.20
# 18                            Roanoke          735                   53.37
# 19               Springfield Shuttles           98                   31.80
# 20                           Borealis          409                   42.33
# 21                   Capitol Corridor          171                   34.27
# 22                         Carolinian          497                   45.31
# 23                           Cascades          462                   44.13
# 24                         Downeaster          145                   33.39
# 25                         Adirondack          327                   39.56
# 26                    Berkshire Flyer          207                   35.49
# 27                Ethan Allen Express          248                   36.88
# 28                         Maple Leaf          471                   44.43
# 29                  New York - Albany          145                   33.39
# 30           New York - Niagara Falls          469                   44.37
# 31                    Heartland Flyer          236                   36.47
# 32                           Hiawatha           82                   31.26
# 33    Carl Sandburg / Illinois Zephyr          257                   37.19
# 34                    Illini / Saluki          304                   38.78
# 35                    Lincoln Service          266                   37.49
# 36                           Keystone          194                   35.05
# 37                 Lincoln / Missouri          537                   46.67
# 38                         Blue Water          319                   39.29
# 39                     Pere Marquette          174                   34.38
# 40                          Wolverine          299                   38.61
# 41                           Missouri          271                   37.66
# 42                  Pacific Surfliner          351                   40.37
# 43                      Pennsylvanian          444                   43.52
# 44                           Piedmont          173                   34.34
# 45                       San Joaquins          372                   41.08
# 46                          Vermonter          602                   48.87
# 47                      Acela Express          457                   43.96

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 7.4 Combine the data [1 pt]
#
# Combine `route_mi_intervals` and `trn_route_mi`. Assign the new `DataFrame` to a variable named
# `lm_predict`. Then sort the `DataFrame` rows by the route miles (ascending) and the sub service
# (descending). Finally, reset the index.

# %%
# Columns in play
cols = [COLS["route_miles"], COLS["predict_avg_mm_late"], COLS["sub_svc"]]

# Concatenate DataFrames, sort, and reset the index
lm_predict = pd.concat([route_mi_intervals, trn_route_mi], ignore_index=True)
lm_predict.sort_values(by=[cols[0], cols[-1]], ascending=[False, True], inplace=True)
lm_predict.reset_index(drop=True, inplace=True)
lm_predict
# Out:
#      Route Miles  Predicted Avg Min Late     Sub Service
# 0           2600                  116.53             NaN
# 1           2575                  115.69             NaN
# 2           2560                  115.18  Empire Builder
# 3           2550                  114.84             NaN
# 4           2525                  113.99             NaN
# ..           ...                     ...             ...
# 148           82                   31.26        Hiawatha
# 149           75                   31.02             NaN
# 150           50                   30.18             NaN
# 151           25                   29.33             NaN
# 152            0                    0.00             NaN
#
# [153 rows x 3 columns]

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 7.5 Write to file [1 pt]
#
# Write `lm_predict` to a CSV file named `stu-amtk-avg_min_late_predict.csv`. Store the file in the
# `data/student` directory. Then compare it to the accompanying `fxt-amtk-avg_min_late_predict.csv` file.
# It must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk-avg_min_late_predict.csv")
lm_predict.to_csv(filepath, index=False)

# %%
# hidden tests are within this cell

# %% [markdown]
# ## 8.0 Watermark

# %%
# %load_ext watermark
# %watermark -h -i -iv -m -v
# Out:
# Python implementation: CPython
# Python version       : 3.11.9
# IPython version      : 8.26.0
#
# Compiler    : GCC 12.3.0
# OS          : Linux
# Release     : 6.5.0-1024-aws
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit
#
# Hostname: 790c9e6d3997
#
# numpy : 2.1.3
# scipy : 1.13.0
# pandas: 2.2.3
