# %% [markdown]
# # Explore: Amtrak Stations
#
# ## Intercity Passenger Rail Service Station Performance Metrics
#
# The Amtrak [network](https://www.amtrak.com/content/dam/projects/dotcom/english/public/documents/Maps/Amtrak-System-Map-020923.pdf)
# is a passenger rail service that provides intercity rail service in the
# continental United States and to select Canadian cities. The network is operated by the
# [National Railroad Passenger Corporation](https://railroads.dot.gov/passenger-rail/amtrak/amtrak),
# a federally chartered for-profit corporation that receives some state funding and covers its
# operating costs by selling tickets and providing other services.
#
# This notebook commences exploration of the augmented quarterly
# [Amtrak](https://www.amtrak.com/home.html) station performance metrics. The goal is to better
# understand individual Amtrak station performance and identify potential areas for further analysis.
#
# ### Variable names
#
# A number of variable names in this project leverage the following abbreviations. The naming
# strategy is to strike a balance between brevity and readability:
#
# * `amtk`: Amtrak (reporting mark)
# * `chrt`: chart
# * `cols`: columns
# * `const`: constant
# * `cwd`: current working directory
# * `eb`: eastbound direction of travel
# * `lm`: linear model
# * `mi`: miles
# * `mm`: minutes (ISO 8601)
# * `nb`: northbound direction of travel
# * `psgr`: passenger
# * `qtr`: quarter
# * `rte`: route
# * `sb`: southbound direction of travel
# * `stats`: summary statistics
# * `stn`: station
# * `stns`: stations
# * `svc`: service
# * `trn`: train
# * `wb`: westbound direction of travel

# %%
import numpy as np
import pandas as pd
import pathlib as pl
import tomllib as tl

import fra_amtrak.amtk_detrain as detrn
import fra_amtrak.amtk_frame as frm
import fra_amtrak.amtk_network as ntwk
import fra_amtrak.chart.chart as chrt
import fra_amtrak.chart.builders.bar_grp_bldr as bar_bld
import fra_amtrak.chart.builders.bxplt_bldr as bxp_bld
import fra_amtrak.chart.builders.hstgrm_bldr as hst_bld
import fra_amtrak.chart.schemas.bar_grp as bar
import fra_amtrak.chart.schemas.bxplt as bxp
import fra_amtrak.chart.schemas.hstgrm as hst

# %%
import warnings, numpy as np, scipy.stats as stats
import fra_amtrak.amtk_detrain as detrn
import fra_amtrak.amtk_frame as frm
import fra_amtrak.amtk_network as ntwk
import pandas as pd

# ── Patch compute_sum_stats ──────────────────────────────────
def compute_sum_stats(frame, agg_columns, agg_funcs, precision=4):
    agg_dict = {col: agg_funcs for col in frame.columns if col in agg_columns}
    return frame.agg(agg_dict).round(precision)
detrn.compute_sum_stats = compute_sum_stats

# ── Patch compute_sum_stats_by_group ────────────────────────
def compute_sum_stats_by_group(frame, groups, agg_columns, agg_funcs, precision=4):
    agg_dict = {col: agg_funcs for col in frame.columns if col in agg_columns}
    return frame.groupby(groups).agg(agg_dict).round(precision)
detrn.compute_sum_stats_by_group = compute_sum_stats_by_group

# ── Patch describe_numeric_column ───────────────────────────
def describe_numeric_column(column):
    try:
        if np.issubdtype(column.dtype, np.number):
            min_ = column.min()
            max_ = column.max()
            return {
                "type": column.__class__, "name": column.name,
                "values": {"non_null": column.count(), "missing": column.isna().sum(), "dtype": column.dtype},
                "center": {"mean": column.mean(), "median": column.median(), "mode": column.mode()[0] if not column.mode().empty else None},
                "position": {"min": np.float64(min_), "25%": np.float64(column.quantile(0.25)), "50%": np.float64(column.quantile()), "75%": np.float64(column.quantile(0.75)), "max": np.float64(max_)},
                "spread": {"variance": column.var(), "std": column.std(), "range": max_ - min_, "iqr": stats.iqr(column)},
                "shape": {"skewness": column.skew(), "kurtosis": column.kurt()}
            }
    except Exception as e:
        warnings.warn(str(e), UserWarning)
    return None
frm.describe_numeric_column = describe_numeric_column

# ── Patch bin_data ───────────────────────────────────────────
def bin_data(frame, column, bins):
    binned_data = frame.copy()
    binned_data["bin"] = pd.cut(binned_data[column], bins=bins, labels=False, include_lowest=True)
    binned_data = binned_data.dropna(subset=["bin"]).copy()
    binned_data["bin"] = binned_data["bin"].astype(int)
    binned_data["bin_start"] = binned_data["bin"].apply(lambda x: bins[x])
    binned_data["bin_end"] = binned_data["bin"].apply(lambda x: bins[x + 1] if x + 1 < len(bins) else bins[x])
    binned_data["bin_center"] = (binned_data["bin_start"] + binned_data["bin_end"]) / 2
    return binned_data
frm.bin_data = bin_data

# ── Patch by_station ─────────────────────────────────────────
def by_station(frame, station_code):
    return frame[frame[COLS["station_code"]] == station_code].reset_index(drop=True)
ntwk.by_station = by_station

# ── Patch get_n_busiest_stations ────────────────────────────
def get_n_busiest_stations(frame, n, group_col=None, year=None, max_quarter=None):
    df = frame.copy()
    if year is not None:
        df = df[df[COLS["year"]] == year]
    if max_quarter is not None:
        df = df[df[COLS["quarter"]] <= max_quarter]
    if group_col is None:
        result = (
            df.groupby([COLS["station_code"], COLS["station"], COLS["city"], COLS["state"], COLS["division"], COLS["region"]])[COLS["total_detrn"]]
            .sum().reset_index()
            .sort_values(by=COLS["total_detrn"], ascending=False)
            .head(n)
            .reset_index(drop=True)
        )
    else:
        result = (
            df.groupby([group_col, COLS["station_code"], COLS["station"], COLS["city"], COLS["state"], COLS["division"], COLS["region"]])[COLS["total_detrn"]]
            .sum().reset_index()
            .sort_values(by=[group_col, COLS["total_detrn"]], ascending=[True, False])
            .groupby(group_col).head(n)
            .reset_index(drop=True)
        )
    return result
ntwk.get_n_busiest_stations = get_n_busiest_stations

print("✓ Semua patch berhasil!")
# Out:
# ✓ Semua patch berhasil!

# %% [markdown]
# ## 1.0 Read files
#
# ### 1.1 Resolve paths

# %%
parent_path = pl.Path.cwd()  # current working directory
parent_path
# Out:
# PosixPath('/home/jovyan/work/assignments/Course4')

# %% [markdown]
# ### 1.2 Load constants
#
# Load a companion [TOML](https://toml.io/en/) file containing constants.

# %%
filepath = parent_path.joinpath("notebook.toml")
with open(filepath, "rb") as file_obj:
    const = tl.load(file_obj)

# Access constants
AGG = const["agg"]
CHRT_BAR = const["chart"]["bar"]
CHRT_BOX = const["chart"]["box"]
COLORS = const["colors"]
COLS = const["columns"]
STNS = const["stations"]

# %% [markdown]
# ### 1.3 Retrieve performance data

# %%
filepath = parent_path.joinpath("data", "processed", "station_performance_metrics-v1p2.csv")
stations = pd.read_csv(
    filepath, dtype={"Address 02": "str", "ZIP Code": "str"}, low_memory=False
)

# %% [markdown]
# ### 1.4 Review the `DataFrame`

# %%
stations.shape
# Out:
# (68412, 24)

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68412 entries, 0 to 68411
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Fiscal Year                               68412 non-null  int64
#  1   Fiscal Quarter                            68412 non-null  int64
#  2   Service Line                              68412 non-null  object
#  3   Service                                   68412 non-null  object
#  4   Sub Service                               68412 non-null  object
#  5   Route Miles                               68412 non-null  int64
#  6   Train Number                              68412 non-null  int64
#  7   Arrival Station Code                      68412 non-null  object
#  8   Arrival Station                           68412 non-null  object
#  9   Arrival Station Type                      68386 non-null  object
#  10  City                                      68404 non-null  object
#  11  Address 01                                68404 non-null  object
#  12  Address 02                                126 non-null    object
#  13  ZIP Code                                  68404 non-null  object
#  14  State                                     68412 non-null  object
#  15  Division                                  68412 non-null  object
#  16  Region                                    68412 non-null  object
#  17  Country                                   68412 non-null  object
#  18  Latitude                                  68404 non-null  float64
#  19  Longitude                                 68404 non-null  float64
#  20  Total Detraining Customers                68412 non-null  int64
#  21  Late Detraining Customers                 68412 non-null  int64
#  22  Late to Total Detraining Customers Ratio  68412 non-null  float64
#  23  Late Detraining Customers Avg Min Late    57373 non-null  float64
# dtypes: float64(4), int64(6), object(14)
# memory usage: 12.5+ MB

# %%
stations.head(3)
# Out:
#    Fiscal Year  Fiscal Quarter   Service Line            Service  \
# 0         2024               3  Long Distance         Auto Train
# 1         2024               3  Long Distance         Auto Train
# 2         2024               3  Long Distance  California Zephyr
#
#          Sub Service  Route Miles  Train Number Arrival Station Code  \
# 0         Auto Train          914            52                  LOR
# 1         Auto Train          914            53                  SFA
# 2  California Zephyr         2408             5                  BRL
#
#         Arrival Station                  Arrival Station Type  ...     State  \
# 0   Lorton (Auto Train)  Station Building (with waiting room)  ...  Virginia
# 1  Sanford (Auto Train)  Station Building (with waiting room)  ...   Florida
# 2            Burlington  Station Building (with waiting room)  ...      Iowa
#
#              Division   Region        Country   Latitude  Longitude  \
# 0      South Atlantic    South  United States  38.708143 -77.220942
# 1      South Atlantic    South  United States  28.808544 -81.291274
# 2  West North Central  Midwest  United States  40.805788 -91.101951
#
#   Total Detraining Customers Late Detraining Customers  \
# 0                      42445                     23316
# 1                      28034                     18439
# 2                        557                       223
#
#    Late to Total Detraining Customers Ratio  \
# 0                                   0.54932
# 1                                   0.65774
# 2                                   0.40036
#
#    Late Detraining Customers Avg Min Late
# 0                                    95.0
# 1                                    91.0
# 2                                    54.0
#
# [3 rows x 24 columns]

# %% [markdown]
# ## 2.0 Passenger arrivals

# %% [markdown]
# ### 2.1 Top 10 stations (entire period)
#
# The function `ntwk.get_n_busiest_stations()` is designed to retrieve the `n` busiest stations. The
# results can be filtered on a geographical unit (e.g., state, divisiion, region) and/or a fiscal year
# and its associated quarters.
#
# Below is listed the top ten (`10`) busiest stations based on passenger arrivals for the entire period under review.

# %%
# Columns of interest (for display output only)
cols = [
    COLS["station_code"],
    COLS["station"],
    COLS["city"],
    COLS["state"],
    COLS["division"],
    COLS["region"],
    COLS["total_detrn"],
]

top_n_stns = ntwk.get_n_busiest_stations(stations, 10)[cols]
top_n_stns
# Out:
#   Arrival Station Code                         Arrival Station          City  \
# 0                  NYP  NY Moynihan Train Hall at Penn Station      New York
# 1                  WAS                              Washington    Washington
# 2                  PHL         Philadelphia (Gray 30th St Sta)  Philadelphia
# 3                  CHI                 Chicago (Union Station)       Chicago
# 4                  BOS                  Boston (South Station)        Boston
# 5                  BAL                Baltimore (Penn Station)     Baltimore
# 6                  LAX                             Los Angeles   Los Angeles
# 7                  NHV               New Haven (Union Station)     New Haven
# 8                  BBY               Boston (Back Bay Station)        Boston
# 9                  ALB                       Albany-Rensselaer    Rensselaer
#
#                   State            Division     Region  \
# 0              New York     Middle Atlantic  Northeast
# 1  District of Columbia      South Atlantic      South
# 2          Pennsylvania     Middle Atlantic  Northeast
# 3              Illinois  East North Central    Midwest
# 4         Massachusetts         New England  Northeast
# 5              Maryland      South Atlantic      South
# 6            California             Pacific       West
# 7           Connecticut         New England  Northeast
# 8         Massachusetts         New England  Northeast
# 9              New York     Middle Atlantic  Northeast
#
#    Total Detraining Customers
# 0                    14571687
# 1                     6648302
# 2                     5852475
# 3                     3728162
# 4                     2202779
# 5                     1522995
# 6                     1383151
# 7                     1133913
# 8                     1121454
# 9                     1105524

# %% [markdown]
# ### 2.2 Top 10 stations (2023 Q1-Q2) [1 pt]
#
# Top ten (`10`) busiest stations based on passenger arrivals for the year `2023`, quarters `01` and
# `02`. This example demonstrates how to filter the data based on a fiscal year and its associated
# quarters.

# %%
top_n_stns = ntwk.get_n_busiest_stations(stations, 10, None, 2023, 2)[cols]
top_n_stns
# Out:
#   Arrival Station Code                         Arrival Station          City  \
# 0                  NYP  NY Moynihan Train Hall at Penn Station      New York
# 1                  WAS                              Washington    Washington
# 2                  PHL         Philadelphia (Gray 30th St Sta)  Philadelphia
# 3                  CHI                 Chicago (Union Station)       Chicago
# 4                  BOS                  Boston (South Station)        Boston
# 5                  BAL                Baltimore (Penn Station)     Baltimore
# 6                  NHV               New Haven (Union Station)     New Haven
# 7                  ALB                       Albany-Rensselaer    Rensselaer
# 8                  BBY               Boston (Back Bay Station)        Boston
# 9                  LAX                             Los Angeles   Los Angeles
#
#                   State            Division     Region  \
# 0              New York     Middle Atlantic  Northeast
# 1  District of Columbia      South Atlantic      South
# 2          Pennsylvania     Middle Atlantic  Northeast
# 3              Illinois  East North Central    Midwest
# 4         Massachusetts         New England  Northeast
# 5              Maryland      South Atlantic      South
# 6           Connecticut         New England  Northeast
# 7              New York     Middle Atlantic  Northeast
# 8         Massachusetts         New England  Northeast
# 9            California             Pacific       West
#
#    Total Detraining Customers
# 0                     2397999
# 1                     1080289
# 2                      962038
# 3                      603897
# 4                      353126
# 5                      245041
# 6                      195653
# 7                      191058
# 8                      183284
# 9                      178735

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 2.3 Top 3 stations (by region, entire period)
#
#  Top three (`3`) busiest stations in each US Census Bureau region based on passenger arrivals.

# %%
def get_n_busiest_stations(frame, n, group_col=None, year=None, max_quarter=None):
    df = frame.copy()
    if year is not None:
        df = df[df[COLS["year"]] == year]
    if max_quarter is not None:
        df = df[df[COLS["quarter"]] <= max_quarter]
    
    # Kolom identitas stasiun
    stn_cols = [COLS["station_code"], COLS["station"], COLS["city"], COLS["state"], COLS["division"], COLS["region"]]
    
    if group_col is None:
        result = (
            df.groupby(stn_cols)[COLS["total_detrn"]]
            .sum()
            .reset_index()
            .sort_values(by=COLS["total_detrn"], ascending=False)
            .head(n)
            .reset_index(drop=True)
        )
    else:
        # Hindari duplikasi: tambahkan group_col hanya jika belum ada di stn_cols
        grp_cols = stn_cols if group_col in stn_cols else [group_col] + stn_cols
        result = (
            df.groupby(grp_cols)[COLS["total_detrn"]]
            .sum()
            .reset_index()
            .sort_values(by=[group_col, COLS["total_detrn"]], ascending=[True, False])
            .groupby(group_col)
            .head(n)
            .reset_index(drop=True)
        )
    return result

ntwk.get_n_busiest_stations = get_n_busiest_stations
print("✓ get_n_busiest_stations patch diperbaiki!")
# Out:
# ✓ get_n_busiest_stations patch diperbaiki!

# %%
region_top_n_stns = ntwk.get_n_busiest_stations(stations, 3, COLS["region"])[cols]
region_top_n_stns
# Out:
#    Arrival Station Code                         Arrival Station          City  \
# 0                   CHI                 Chicago (Union Station)       Chicago
# 1                   MKE                    Milwaukee (Downtown)     Milwaukee
# 2                   STL                               St. Louis     St. Louis
# 3                   NYP  NY Moynihan Train Hall at Penn Station      New York
# 4                   PHL         Philadelphia (Gray 30th St Sta)  Philadelphia
# 5                   BOS                  Boston (South Station)        Boston
# 6                   WAS                              Washington    Washington
# 7                   BAL                Baltimore (Penn Station)     Baltimore
# 8                   BWI   BWI Thurgood Marshall Airport Station     Baltimore
# 9                   LAX                             Los Angeles   Los Angeles
# 10                  SAC                              Sacramento    Sacramento
# 11                  SEA           Seattle (King Street Station)       Seattle
#
#                    State            Division     Region  \
# 0               Illinois  East North Central    Midwest
# 1              Wisconsin  East North Central    Midwest
# 2               Missouri  West North Central    Midwest
# 3               New York     Middle Atlantic  Northeast
# 4           Pennsylvania     Middle Atlantic  Northeast
# 5          Massachusetts         New England  Northeast
# 6   District of Columbia      South Atlantic      South
# 7               Maryland      South Atlantic      South
# 8               Maryland      South Atlantic      South
# 9             California             Pacific       West
# 10            California             Pacific       West
# 11            Washington             Pacific       West
#
#     Total Detraining Customers
# 0                      3728162
# 1                       647676
# 2                       476491
# 3                     14571687
# 4                      5852475
# 5                      2202779
# 6                      6648302
# 7                      1522995
# 8                      1012325
# 9                      1383151
# 10                      752435
# 11                      723183

# %% [markdown]
# ### 2.4 Top 3 stations (by division, entire period)
#
# Top three (`3`) busiest stations in each US Census Bureau division based on passenger arrivals.

# %%
div_top_n_stns = ntwk.get_n_busiest_stations(stations, 3, COLS["division"])[cols]
div_top_n_stns
# Out:
#    Arrival Station Code                         Arrival Station  \
# 0                   CHI                 Chicago (Union Station)
# 1                   MKE                    Milwaukee (Downtown)
# 2                   BNL                      Bloomington-Normal
# 3                   MEM                                 Memphis
# 4                   JAN                                 Jackson
# 5                   BHM                              Birmingham
# 6                   MTR                Montreal (Gare Centrale)
# 7                   NFS                           Niagara Falls
# 8                   SLQ                              St-Lambert
# 9                   NYP  NY Moynihan Train Hall at Penn Station
# 10                  PHL         Philadelphia (Gray 30th St Sta)
# 11                  ALB                       Albany-Rensselaer
# 12                  DEN                  Denver (Union Station)
# 13                  RNO                                    Reno
# 14                  ABQ                             Albuquerque
# 15                  BOS                  Boston (South Station)
# 16                  NHV               New Haven (Union Station)
# 17                  BBY               Boston (Back Bay Station)
# 18                  LAX                             Los Angeles
# 19                  SAC                              Sacramento
# 20                  SEA           Seattle (King Street Station)
# 21                  WAS                              Washington
# 22                  BAL                Baltimore (Penn Station)
# 23                  BWI   BWI Thurgood Marshall Airport Station
# 24                  STL                               St. Louis
# 25                  KCY             Kansas City (Union Station)
# 26                  MSP                    St. Paul-Minneapolis
# 27                  NOL                             New Orleans
# 28                  FTW                              Fort Worth
# 29                  SAS                             San Antonio
# 30                  VAC                               Vancouver
#
#              City                 State            Division     Region  \
# 0         Chicago              Illinois  East North Central    Midwest
# 1       Milwaukee             Wisconsin  East North Central    Midwest
# 2          Normal              Illinois  East North Central    Midwest
# 3         Memphis             Tennessee  East South Central      South
# 4         Jackson           Mississippi  East South Central      South
# 5      Birmingham               Alabama  East South Central      South
# 6        Montreal                Quebec      Eastern Canada  Northeast
# 7   Niagara Falls               Ontario      Eastern Canada  Northeast
# 8      St-Lambert                Quebec      Eastern Canada  Northeast
# 9        New York              New York     Middle Atlantic  Northeast
# 10   Philadelphia          Pennsylvania     Middle Atlantic  Northeast
# 11     Rensselaer              New York     Middle Atlantic  Northeast
# 12         Denver              Colorado            Mountain       West
# 13           Reno                Nevada            Mountain       West
# 14    Albuquerque            New Mexico            Mountain       West
# 15         Boston         Massachusetts         New England  Northeast
# 16      New Haven           Connecticut         New England  Northeast
# 17         Boston         Massachusetts         New England  Northeast
# 18    Los Angeles            California             Pacific       West
# 19     Sacramento            California             Pacific       West
# 20        Seattle            Washington             Pacific       West
# 21     Washington  District of Columbia      South Atlantic      South
# 22      Baltimore              Maryland      South Atlantic      South
# 23      Baltimore              Maryland      South Atlantic      South
# 24      St. Louis              Missouri  West North Central    Midwest
# 25    Kansas City              Missouri  West North Central    Midwest
# 26       St. Paul             Minnesota  West North Central    Midwest
# 27    New Orleans             Louisiana  West South Central      South
# 28     Fort Worth                 Texas  West South Central      South
# 29    San Antonio                 Texas  West South Central      South
# 30      Vancouver      British Columbia      Western Canada       West
#
#     Total Detraining Customers
# 0                      3728162
# 1                       647676
# 2                       296534
# 3                        76373
# 4                        46701
# 5                        41606
# 6                        22430
# 7                        21447
# 8                          859
# 9                     14571687
# 10                     5852475
# 11                     1105524
# 12                      148077
# 13                       83967
# 14                       67844
# 15                     2202779
# 16                     1133913
# 17                     1121454
# 18                     1383151
# 19                      752435
# 20                      723183
# 21                     6648302
# 22                     1522995
# 23                     1012325
# 24                      476491
# 25                      182005
# 26                      106785
# 27                      201372
# 28                      155747
# 29                       69675
# 30                      145471

# %% [markdown]
# ### 2.5 Top 3 stations (by state)
#
# The top three (`3`) busiest stations in each state based on passenger arrivals.

# %%
state_top_n_stns = ntwk.get_n_busiest_stations(stations, 3, COLS["state"])[cols]
state_top_n_stns
# Out:
#     Arrival Station Code             Arrival Station           City  \
# 0                    BHM                  Birmingham     Birmingham
# 1                    TCL                  Tuscaloosa     Tuscaloosa
# 2                    ATN                    Anniston       Anniston
# 3                    FLG  Flagstaff (Amtrak Station)      Flagstaff
# 4                    TUS                      Tucson         Tucson
# ..                   ...                         ...            ...
# 136                  HFY               Harpers Ferry  Harpers Ferry
# 137                  CHW                  Charleston     Charleston
# 138                  MKE        Milwaukee (Downtown)      Milwaukee
# 139                  MKA  Milwaukee Airport (Trains)      Milwaukee
# 140                  SVT                  Sturtevant     Sturtevant
#
#              State            Division   Region  Total Detraining Customers
# 0          Alabama  East South Central    South                       41606
# 1          Alabama  East South Central    South                       11481
# 2          Alabama  East South Central    South                        4731
# 3          Arizona            Mountain     West                       40203
# 4          Arizona            Mountain     West                       28936
# ..             ...                 ...      ...                         ...
# 136  West Virginia      South Atlantic    South                        9517
# 137  West Virginia      South Atlantic    South                        9325
# 138      Wisconsin  East North Central  Midwest                      647676
# 139      Wisconsin  East North Central  Midwest                      145344
# 140      Wisconsin  East North Central  Midwest                       57647
#
# [141 rows x 7 columns]

# %% [markdown]
# ## 3.0 Select Station metrics
#
# ### 3.1 Moynihan Train Hall at Penn Station (NYP), New York, NY
#
# [Moynihan Train Hall](https://www.amtrak.com/stations/nyp) at Penn Station ([NYP](https://www.amtrak.com/stations/nyp)) is a major
# transportation hub and Amtrak's busiest station.

# %%
# All fiscal years and quarters
nyp = ntwk.by_station(stations, "NYP")
nyp.shape
# Out:
# (1719, 24)

# %% [markdown]
# ### 3.2 NYP: on-time performance metrics (entire period)
#
# NYP station performance data is a compilation of quarterly metrics that focus on late
# detraining passengers. Detraining assengers are considered on-time if they arrive at their
# destination no later than fifteen (`15`) minutes after their scheduled arrival time. All other
# detraining passengers are considered late.

# %%
# Train arrivals (total)
nyp_trn_arrivals = nyp.shape[0]

# Detraining totals
nyp_detrn = nyp[COLS["total_detrn"]].sum()
nyp_detrn_late = nyp[COLS["late_detrn"]].sum()
nyp_detrn_on_time = nyp_detrn - nyp_detrn_late

print(
    f"Train Arrivals: {nyp_trn_arrivals}",
    f"Total Detraining Customers: {nyp_detrn}",
    f"Late Detraining Customers: {nyp_detrn_late}",
    f"On-Time Detraining Customers: {nyp_detrn_on_time}",
    sep="\n",
)

nyp_stats = detrn.get_sum_stats(nyp, AGG["columns"], AGG["funcs"])
nyp_stats
# Out:
# Train Arrivals: 1719
# Total Detraining Customers: 14571687
# Late Detraining Customers: 2497718
# On-Time Detraining Customers: 12073969
#    Train Arrivals  Total Detraining Customers sum  \
# 0            1719                      14571687.0
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                        8476.8394                             7861.0
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                       5390.6046                      2497718.0
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                       1453.0064                             884.0
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                      1724.1642                                    0.1714
#
#   Late Detraining Customers Avg Min Late mean  \
# 0                                        None
#
#    Total On Time Detraining Customers sum
# 0                              12073969.0

# %% [markdown]
# ### 3.3 NYP: mean late arrival times summary statistics
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of NYP trains. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics.

# %%
# Drop missing values
nyp_avg_mm_late = nyp[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Call the custom frm.describe_numeric_column() function again
nyp_avg_mm_late_describe = frm.describe_numeric_column(nyp_avg_mm_late)
nyp_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(1579),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(43.91703609879671),
#   'median': 37.0,
#   'mode': np.float64(28.0)},
#  'position': {'min': np.float64(11.0),
#   '25%': np.float64(27.0),
#   '50%': np.float64(37.0),
#   '75%': np.float64(51.0),
#   'max': np.float64(620.0)},
#  'spread': {'variance': 993.9924789156773,
#   'std': 31.52764626348877,
#   'range': 609.0,
#   'iqr': np.float64(24.0)},
#  'shape': {'skewness': np.float64(6.254233955826336),
#   'kurtosis': np.float64(82.83535199296716)}}

# %% [markdown]
# The skewness and kurtosis values returned suggest that the distribution of mean late arrival times of NYP trains are positively skewed and features a sharper peak and heavier right tail than a normal distribution. Let's confirm this visually by generating a histogram.

# %% [markdown]
# ### 3.4 NYP: visualize distribution of mean late arrival times
#
# Visualize mean late arrival times for the entire period. The data is binned prior to plotting.
#
# #### 3.4.1 Create chart data

# %%
# Convert to DataFrame
nyp_avg_mm_late = nyp_avg_mm_late.to_frame(name=COLS["avg_mm_late"])

# Get mean and standard deviation
mu = nyp_avg_mm_late_describe["center"]["mean"]
sigma = nyp_avg_mm_late_describe["spread"]["std"]

# Get max value (for x-axis ticks); pad max value for chart display
max_val = nyp_avg_mm_late_describe["position"]["max"]
max_val_ceil = (np.ceil(max_val / 10) * 10).astype(float)

# Create bins
nyp_mm_late, bins, num_bins, bin_width = frm.create_bins(nyp_avg_mm_late, COLS["avg_mm_late"], 15)

# Bin the data
chrt_data = frm.bin_data(nyp_mm_late, COLS["avg_mm_late"], bins)

# chrt_data

# %% [markdown]
# #### 3.4.2 Generate the histogram

# %%
title = chrt.format_title(nyp_stats, f"Late Detraining Passengers: {STNS['nyp']}")
chart = (
    hst_bld.HistogramBuilder(hst.HistogramChart(frame=chrt_data, title=title))
    .x(
        axis_tick_count=max_val_ceil,
        axis_values=np.arange(0.0, max_val_ceil + 15, 5).tolist(),  # Use np.arange for array of float values
        bin_max_bins=num_bins,
        bin_step=bin_width,
        scale_domain=[0.0, max_val_ceil],
    )
    .mu_rule(mu=mu)
    .sigma_rules(sigma=sigma, n=2)
    .build()
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### 3.5 NYP: on-time performance metrics (by fiscal year and quarter)
#
# Compute OTP summary statistics per fiscal year and quarter. Add quarterly train arrival metrics to
# the `DataFrame` named `nyp_qtr_stats`.

# %%
nyp_qtr_stats = detrn.get_sum_stats_by_group(
    nyp,
    [COLS["year"], COLS["quarter"]],
    AGG["columns"],   # ← columns dulu
    AGG["funcs"],     # ← baru funcs
    nyp_trn_arrivals,
    nyp_detrn,
)
nyp_qtr_stats.sort_values(by=[COLS["year"], COLS["quarter"]], ascending=[True, True])
# Out:
#     Fiscal Year  Fiscal Quarter  Train Arrivals  Train Arrival Ratio  \
# 0          2021               4             103             0.059919
# 1          2022               1             129             0.075044
# 2          2022               2             126             0.073298
# 3          2022               3             130             0.075625
# 4          2022               4             134             0.077952
# 5          2023               1             146             0.084933
# 6          2023               2             138             0.080279
# 7          2023               3             162             0.094241
# 8          2023               4             154             0.089587
# 9          2024               1             158             0.091914
# 10         2024               2             172             0.100058
# 11         2024               3             167             0.097150
#
#     Detraining Ratio  Total Detraining Customers sum  \
# 0           0.048781                          710825
# 1           0.069116                         1007131
# 2           0.050477                          735530
# 3           0.079590                         1159760
# 4           0.086093                         1254516
# 5           0.089987                         1311263
# 6           0.074579                         1086736
# 7           0.093413                         1361186
# 8           0.103743                         1511712
# 9           0.104808                         1527234
# 10          0.093147                         1357308
# 11          0.106267                         1548486
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                         6901.2136                             6243.0
# 1                         7807.2171                             7300.0
# 2                         5837.5397                             5627.0
# 3                         8921.2308                             8654.0
# 4                         9362.0597                             9357.5
# 5                         8981.2534                             8448.5
# 6                         7874.8986                             7700.0
# 7                         8402.3827                             7659.0
# 8                         9816.3117                             9211.0
# 9                         9666.0380                             8891.0
# 10                        7891.3256                             7475.5
# 11                        9272.3713                             8377.0
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                        4148.4920                          94408
# 1                        4996.9533                         133399
# 2                        3910.4336                          93814
# 3                        5247.1844                         161258
# 4                        5526.6458                         266192
# 5                        5901.8054                         226136
# 6                        4474.3212                         117626
# 7                        5519.8425                         265248
# 8                        5623.7868                         336474
# 9                        6194.7703                         267687
# 10                       5024.8321                         197328
# 11                       5751.4898                         338148
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                         916.5825                             647.0
# 1                        1034.1008                             748.0
# 2                         744.5556                             536.0
# 3                        1240.4462                             724.5
# 4                        1986.5075                            1233.5
# 5                        1548.8767                            1061.5
# 6                         852.3623                             489.5
# 7                        1637.3333                            1124.0
# 8                        2184.8961                            1387.0
# 9                        1694.2215                            1120.5
# 10                       1147.2558                             833.5
# 11                       2024.8383                            1165.0
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                       1147.1338                                    0.1328
# 1                       1000.3398                                    0.1325
# 2                        804.6166                                    0.1275
# 3                       1546.5171                                    0.1390
# 4                       2066.1894                                    0.2122
# 5                       1783.1140                                    0.1725
# 6                        989.5623                                    0.1082
# 7                       1862.6475                                    0.1949
# 8                       2173.3855                                    0.2226
# 9                       1769.6038                                    0.1753
# 10                      1091.7280                                    0.1454
# 11                      2376.0149                                    0.2184
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       46.0588
# 1                                       39.7913
# 2                                       47.4554
# 3                                       43.4138
# 4                                       39.8485
# 5                                       47.0074
# 6                                       44.1557
# 7                                       40.3642
# 8                                       47.2039
# 9                                       41.7838
# 10                                      43.4076
# 11                                      47.0195
#
#     Total On Time Detraining Customers sum
# 0                                   616417
# 1                                   873732
# 2                                   641716
# 3                                   998502
# 4                                   988324
# 5                                  1085127
# 6                                   969110
# 7                                  1095938
# 8                                  1175238
# 9                                  1259547
# 10                                 1159980
# 11                                 1210338

# %% [markdown]
# #### 3.5.1 Write to file [1 pt]
#
# Write `nyp_qtr_stats` to a CSV file named `stu-amtk-nyp_qtr_stats.csv`. Store the file in the
# `data/student` directory. Then compare it to the accompanying `fxt-amtk-nyp_qtr_stats.csv` file. It
# must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk-nyp_qtr_stats.csv")
nyp_qtr_stats.to_csv(filepath)

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 3.6 NYP: visualize detraining passengers
#
# Visualize NYP detraining passengers, both on-time and late, across all years and quarters with a
# bar chart.

# %%
def drop_dups_and_squeeze(frame, columns):
    """Drop duplicate rows based on columns, then squeeze to a Series."""
    result = frame[columns].drop_duplicates().reset_index(drop=True)
    if len(result) == 1:
        return result.squeeze()  # Kembalikan sebagai Series jika hanya 1 baris
    return result.iloc[0]  # Ambil baris pertama jika ada lebih dari 1

frm.drop_dups_and_squeeze = drop_dups_and_squeeze
print("✓ drop_dups_and_squeeze patch berhasil!")
# Out:
# ✓ drop_dups_and_squeeze patch berhasil!

# %%
# Assemble the data for the chart
chrt_data = detrn.create_detrain_chart_frame(nyp_qtr_stats, CHRT_BAR["columns"])

# Get station code, station name, city, and state to use in the chart title
text = frm.drop_dups_and_squeeze(
    nyp, [COLS["station_code"], COLS["station"], COLS["city"], COLS["state"]]
)

# Chart title
title_txt = (
    f"Detraining Passengers: {text['Arrival Station']} ({text['Arrival Station Code']}), "
    f"{text['City']}, {text['State']}"
)
title = chrt.format_title(nyp_stats, title_txt)

chart = bar_bld.GrpBarBuilder(bar.GrpBarChart(frame=chrt_data, title=title)).build()
chart.display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 3.7 NYP: On-time performance metrics by service line
#
# Group train arrivals by service line.

# %%
nyp_svc_trns = nyp.groupby(COLS["svc_line"]).size().reset_index()  # Includes rows with NaN
nyp_svc_trns.columns = [COLS["svc_line"], COLS["trn_arrivals"]]
nyp_svc_trns.sort_values(by=COLS["trn_arrivals"], ascending=False, inplace=True)
nyp_svc_trns.reset_index(drop=True, inplace=True)

# Add train arrival ratios (year_qtr/total)
nyp_svc_trns.loc[:, COLS["trn_arrival_ratio"]] = (
    nyp_svc_trns[COLS["trn_arrivals"]] / nyp_trn_arrivals
)
nyp_svc_trns
# Out:
#          Service Line  Train Arrivals  Train Arrival Ratio
# 0  Northeast Corridor            1207             0.702152
# 1     State Supported             448             0.260617
# 2       Long Distance              64             0.037231

# %% [markdown]
# #### 3.7.1 NYP: compute on-time performance metrics by service line. [1 pt]

# %%
# Get summary stats by COLS["svc_line"]
nyp_svc_line_stats = detrn.get_sum_stats_by_group(
    nyp, COLS["svc_line"], AGG["columns"], AGG["funcs"]
)

# Merge train arrivals by service line
nyp_svc_line_stats = nyp_svc_line_stats.merge(nyp_svc_trns, on=COLS["svc_line"], how="inner")

# Move train arrival columns
cols = nyp_svc_line_stats.columns.tolist()
cols = [cols[0]] + cols[-2:] + cols[1:-2]
nyp_svc_line_stats = nyp_svc_line_stats[cols]

# Add service line detraining ratios
nyp_svc_line_stats.loc[:, "Service Line Detraining Ratio"] = (
    nyp_svc_line_stats["Total Detraining Customers sum"] / nyp_detrn
)

# Move service line detraining ratio column
nyp_svc_line_stats.insert(
    3, "Service Line Detraining Ratio", nyp_svc_line_stats.pop("Service Line Detraining Ratio")
)

# Sort by passengers detrained (descending order)
nyp_svc_line_stats.sort_values(by="Total Detraining Customers sum", ascending=False, inplace=True)

# Reset index
nyp_svc_line_stats.reset_index(drop=True, inplace=True)
nyp_svc_line_stats
# Out:
#          Service Line  Train Arrivals_y  Train Arrival Ratio  \
# 0       Long Distance                64             0.037231
# 1     State Supported               448             0.260617
# 2  Northeast Corridor              1207             0.702152
#
#    Service Line Detraining Ratio  Train Arrivals_x  \
# 0                       0.031552                64
# 1                       0.317086               448
# 2                       0.651362              1207
#
#    Total Detraining Customers sum  Total Detraining Customers mean  \
# 0                          459772                        7183.9375
# 1                         4620479                       10313.5692
# 2                         9491436                        7863.6587
#
#    Total Detraining Customers median  Total Detraining Customers std  \
# 0                             6890.0                       4345.8832
# 1                             9945.0                       5816.6205
# 2                             7326.0                       5113.7391
#
#    Late Detraining Customers sum  Late Detraining Customers mean  \
# 0                         173780                       2715.3125
# 1                         617090                       1377.4330
# 2                        1706848                       1414.1243
#
#    Late Detraining Customers median  Late Detraining Customers std  \
# 0                            2072.5                      1978.3820
# 1                             790.5                      1685.7938
# 2                             907.0                      1699.6482
#
#    Late to Total Detraining Customers Ratio  \
# 0                                    0.3780
# 1                                    0.1336
# 2                                    0.1798
#
#    Late Detraining Customers Avg Min Late mean  \
# 0                                      89.3594
# 1                                      42.8652
# 2                                      41.6775
#
#    Total On Time Detraining Customers sum
# 0                                  285992
# 1                                 4003389
# 2                                 7784588

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 3.7.2 NYP: visualize distribution of mean late arrival times
#
# Illustrate with box plots.

# %%
nyp_svc_lines = nyp.groupby(COLS["svc_line"])[[COLS["svc_line"], COLS["late_detrn_avg_mm_late"]]]
chrt_data = nyp_svc_lines.apply(lambda x: x).reset_index(drop=True)  # Flatten for Altair
chrt_data.head()
# Out:
#     Service Line  Late Detraining Customers Avg Min Late
# 0  Long Distance                                   103.0
# 1  Long Distance                                    82.0
# 2  Long Distance                                    40.0
# 3  Long Distance                                    75.0
# 4  Long Distance                                   110.0

# %%
title_txt = (
    f"Late Detraining Passengers: {text['Arrival Station']} ({text['Arrival Station Code']}), "
    f"{text['City']}, {text['State']}"
)
title = chrt.format_title(nyp_stats, title_txt)

chart = bxp_bld.BoxPlotBuilder(bxp.BoxplotChart(frame=chrt_data, title=title)).build()
chart.display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 3.8 Chicago Union Station (CHI), Chicago, IL
#
# [Chicago Union Station](https://www.amtrak.com/stations/chi) ([CHI](https://www.amtrak.com/stations/chi)) is a key node in the Amtrak
# network, supporting both regional services in the Midwest and long distance routes.

# %%
chi = ntwk.by_station(stations, "CHI")
chi.shape
# Out:
# (334, 24)

# %% [markdown]
# ### 3.9 CHI: on-time performance metrics (entire period)
#
# CHI station performance data is a compilation of quarterly metrics that focus on late
# detraining passengers. Detraining assengers are considered on-time if they arrive at their
# destination no later than fifteen (`15`) minutes after their scheduled arrival time. All other
# detraining passengers are considered late.

# %%
# Train arrivals (total)
chi_trn_arrivals = chi.shape[0]

# Detraining totals
chi_detrn = chi[COLS["total_detrn"]].sum()
chi_detrn_late = chi[COLS["late_detrn"]].sum()
chi_detrn_on_time = chi_detrn - chi_detrn_late

print(
    f"Train Arrivals: {chi_trn_arrivals}",
    f"Total Detraining Customers: {chi_detrn}",
    f"Late Detraining Customers: {chi_detrn_late}",
    f"On-Time Detraining Customers: {chi_detrn_on_time}",
    sep="\n",
)

chi_stats = detrn.get_sum_stats(chi, AGG["columns"], AGG["funcs"])
chi_stats
# Out:
# Train Arrivals: 334
# Total Detraining Customers: 3728162
# Late Detraining Customers: 1068254
# On-Time Detraining Customers: 2659908
#    Train Arrivals  Total Detraining Customers sum  \
# 0             334                       3728162.0
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                       11162.1617                            11178.5
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                       5128.1625                      1068254.0
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                       3198.3653                            2343.0
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                      2996.0464                                    0.2865
#
#   Late Detraining Customers Avg Min Late mean  \
# 0                                        None
#
#    Total On Time Detraining Customers sum
# 0                               2659908.0

# %% [markdown]
# ### 3.10 CHI: mean late arrival times summary statistics
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of CHI trains. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics.

# %%
# Drop missing values
chi_avg_mm_late = chi[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Call the custom frm.describe_numeric_column() function again
chi_avg_mm_late_describe = frm.describe_numeric_column(chi_avg_mm_late)
chi_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(329),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(70.48936170212765),
#   'median': 49.0,
#   'mode': np.float64(36.0)},
#  'position': {'min': np.float64(17.0),
#   '25%': np.float64(37.0),
#   '50%': np.float64(49.0),
#   '75%': np.float64(75.0),
#   'max': np.float64(516.0)},
#  'spread': {'variance': 4145.0128437986505,
#   'std': 64.38177415851982,
#   'range': 499.0,
#   'iqr': np.float64(38.0)},
#  'shape': {'skewness': np.float64(3.6196602828263766),
#   'kurtosis': np.float64(17.251866900544588)}}

# %% [markdown]
# The skewness and kurtosis values returned suggest that the distribution of mean late arrival times of CHI trains are positively skewed and features features a sharper peak and heavier right tail than a normal distribution. Let's confirm this visually by generating a histogram.

# %% [markdown]
# ### 3.11 CHI: visualize distribution of mean late arrival times
#
# Visualize mean late arrival times for the entire period. The data is binned prior to plotting.
#
# #### 3.11.1 Create chart data [1 pt]

# %%
# Convert to DataFrame
chi_avg_mm_late = chi_avg_mm_late.to_frame(name=COLS["avg_mm_late"])

# Get mean and standard deviation
mu = chi_avg_mm_late_describe["center"]["mean"]
sigma = chi_avg_mm_late_describe["spread"]["std"]

# Get max value (for x-axis ticks); pad max value for chart display
max_val = chi_avg_mm_late_describe["position"]["max"]
max_val_ceil = (np.ceil(max_val / 10) * 10).astype(float)

# Create bins
chi_mm_late, bins, num_bins, bin_width = frm.create_bins(chi_avg_mm_late, COLS["avg_mm_late"], 10)

# Bin the data
chrt_data = frm.bin_data(chi_mm_late, COLS["avg_mm_late"], bins)
# chrt_data

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 3.11.2 Generate the histogram

# %%
title = chrt.format_title(chi_stats, f"Late Detraining Passengers: {STNS['chi']}")

chart = (
    hst_bld.HistogramBuilder(hst.HistogramChart(frame=chrt_data, title=title))
    .x(
        axis_tick_count=max_val_ceil,
        axis_values=np.arange(0.0, max_val_ceil + 15, 5).tolist(),  # Use np.arange for array of float values
        bin_max_bins=num_bins,
        bin_step=bin_width,
        scale_domain=[0.0, max_val_ceil],
    )
    .mu_rule(mu=mu)
    .sigma_rules(sigma=sigma, n=2)
    .build()
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### 3.12 CHI: on-time performance metrics (by fiscal year and quarter) [1 pt]
#
# Compute OTP summary statistics per fiscal year and quarter. Add quarterly train arrival metrics to
# the `DataFrame` named `chi_qtr_stats`.

# %%
chi_qtr_stats = detrn.get_sum_stats_by_group(
    chi, [COLS["year"], COLS["quarter"]], AGG["columns"], AGG["funcs"],
    chi_trn_arrivals,  # ← tambahkan ini
    chi_detrn,
)
chi_qtr_stats.sort_values(by=[COLS["year"], COLS["quarter"]], ascending=[True, True])
# Out:
#     Fiscal Year  Fiscal Quarter  Train Arrivals  Train Arrival Ratio  \
# 0          2021               4              13             0.000003
# 1          2022               1              28             0.000008
# 2          2022               2              31             0.000008
# 3          2022               3              28             0.000008
# 4          2022               4              28             0.000008
# 5          2023               1              29             0.000008
# 6          2023               2              31             0.000008
# 7          2023               3              28             0.000008
# 8          2023               4              28             0.000008
# 9          2024               1              29             0.000008
# 10         2024               2              32             0.000009
# 11         2024               3              29             0.000008
#
#     Total Detraining Customers sum  Total Detraining Customers mean  \
# 0                           111344                        8564.9231
# 1                           298127                       10647.3929
# 2                           208750                        6733.8710
# 3                           326087                       11645.9643
# 4                           359202                       12828.6429
# 5                           329989                       11378.9310
# 6                           273908                        8835.7419
# 7                           362468                       12945.2857
# 8                           389237                       13901.3214
# 9                           381496                       13155.0345
# 10                          308523                        9641.3438
# 11                          379031                       13070.0345
#
#     Total Detraining Customers median  Total Detraining Customers std  \
# 0                              8783.0                       3040.1924
# 1                             10743.0                       3874.3448
# 2                              7099.0                       4129.6256
# 3                             11799.0                       4485.1134
# 4                             13513.5                       5632.3036
# 5                             10888.0                       5523.3084
# 6                              9530.0                       4431.7537
# 7                             13578.0                       4478.6503
# 8                             14293.5                       5139.2710
# 9                             12472.0                       5345.1562
# 10                            10364.0                       4888.0106
# 11                            12793.0                       4394.3717
#
#     Late Detraining Customers sum  Late Detraining Customers mean  \
# 0                           10687                        822.0769
# 1                           85085                       3038.7500
# 2                           71142                       2294.9032
# 3                          118808                       4243.1429
# 4                          122908                       4389.5714
# 5                           92802                       3200.0690
# 6                           70810                       2284.1935
# 7                          109215                       3900.5357
# 8                          125618                       4486.3571
# 9                           85648                       2953.3793
# 10                          70619                       2206.8438
# 11                         104912                       3617.6552
#
#     Late Detraining Customers median  Late Detraining Customers std  \
# 0                              391.0                       954.2883
# 1                             2406.5                      2772.3757
# 2                             1750.0                      2131.3324
# 3                             2963.5                      4076.5326
# 4                             3151.0                      4049.1612
# 5                             2318.0                      2625.2786
# 6                             1827.0                      1978.7552
# 7                             2541.5                      3641.1660
# 8                             2867.0                      3852.7373
# 9                             2563.0                      1976.6944
# 10                            2160.5                      1611.7561
# 11                            3418.0                      2602.8834
#
#     Late to Total Detraining Customers Ratio  \
# 0                                     0.0960
# 1                                     0.2854
# 2                                     0.3408
# 3                                     0.3643
# 4                                     0.3422
# 5                                     0.2812
# 6                                     0.2585
# 7                                     0.3013
# 8                                     0.3227
# 9                                     0.2245
# 10                                    0.2289
# 11                                    0.2768
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       55.0769
# 1                                       56.4286
# 2                                       68.6667
# 3                                       64.8519
# 4                                       72.0741
# 5                                       82.1379
# 6                                       99.5333
# 7                                       60.7500
# 8                                       64.1071
# 9                                       81.1034
# 10                                      66.4194
# 11                                      64.2414
#
#     Total On Time Detraining Customers sum
# 0                                   100657
# 1                                   213042
# 2                                   137608
# 3                                   207279
# 4                                   236294
# 5                                   237187
# 6                                   203098
# 7                                   253253
# 8                                   263619
# 9                                   295848
# 10                                  237904
# 11                                  274119

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 3.12.1 Write to file [1 pt]
#
# Write `chi_qtr_stats` to a CSV file named `stu-amtk-chi_qtr_stats.csv`. Store the file in the
# `data/student` directory. Then compare it to the accompanying `fxt-amtk-chi_qtr_stats.csv` file. It
# must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk-chi_qtr_stats.csv")
chi_qtr_stats.to_csv(filepath)

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 3.13 CHI: visualize detraining passengers
#
# Visualize CHI detraining passengers, both on-time and late, across all years and quarters with a
# bar chart.

# %%
# Assemble the data for the chart
chrt_data = detrn.create_detrain_chart_frame(chi_qtr_stats, CHRT_BAR["columns"])

# Get station code, station name, city, and state to use in the chart title
text = frm.drop_dups_and_squeeze(
    chi, [COLS["station_code"], COLS["station"], COLS["city"], COLS["state"]]
)

# Chart title
title_txt = (
    f"Detraining Passengers: {text['Arrival Station']} ({text['Arrival Station Code']}), "
    f"{text['City']}, {text['State']}"
)
title = chrt.format_title(chi_stats, title_txt)

chart = bar_bld.GrpBarBuilder(bar.GrpBarChart(frame=chrt_data, title=title)).build()
chart.display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 3.14 CHI: On-time performance metrics by service line [1 pt]
#
# Group train arrivals by service line.

# %%
chi_svc_trns = chi.groupby(COLS["svc_line"]).size().reset_index()  # Includes rows with NaN
chi_svc_trns.columns = [COLS["svc_line"], COLS["trn_arrivals"]]
chi_svc_trns.sort_values(by=COLS["trn_arrivals"], ascending=False, inplace=True)
chi_svc_trns.reset_index(drop=True, inplace=True)

# Add train arrival ratios (year_qtr/total)
chi_svc_trns.loc[:, COLS["trn_arrival_ratio"]] = (
    chi_svc_trns[COLS["trn_arrivals"]] / chi_trn_arrivals  # ← balik urutan
)
chi_svc_trns
# Out:
#       Service Line  Train Arrivals  Train Arrival Ratio
# 0  State Supported             233             1.433476
# 1    Long Distance             101             3.306931

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 3.14.1 CHI: compute on-time performance metrics by service line.

# %%
# Get summary stats by COLS["svc_line"]
chi_svc_line_stats = detrn.get_sum_stats_by_group(
    chi, COLS["svc_line"], AGG["columns"], AGG["funcs"]
)

# Merge train arrivals by service line
chi_svc_line_stats = chi_svc_line_stats.merge(chi_svc_trns, on=COLS["svc_line"], how="inner")

# Move train arrival columns
cols = chi_svc_line_stats.columns.tolist()
cols = [cols[0]] + cols[-2:] + cols[1:-2]
chi_svc_line_stats = chi_svc_line_stats[cols]

# Add service line detraining ratios
chi_svc_line_stats.loc[:, "Service Line Detraining Ratio"] = (
    chi_svc_line_stats["Total Detraining Customers sum"] / chi_detrn
)

# Move service line detraining ratio column
chi_svc_line_stats.insert(
    3, "Service Line Detraining Ratio", chi_svc_line_stats.pop("Service Line Detraining Ratio")
)

# Sort by passengers detrained (descending order)
chi_svc_line_stats.sort_values(by="Total Detraining Customers sum", ascending=False, inplace=True)

# Reset index
chi_svc_line_stats.reset_index(drop=True, inplace=True)
chi_svc_line_stats
# Out:
#       Service Line  Train Arrivals_y  Train Arrival Ratio  \
# 0  State Supported               233             1.433476
# 1    Long Distance               101             3.306931
#
#    Service Line Detraining Ratio  Train Arrivals_x  \
# 0                       0.718483               233
# 1                       0.281517               101
#
#    Total Detraining Customers sum  Total Detraining Customers mean  \
# 0                         2678621                       11496.2275
# 1                         1049541                       10391.4950
#
#    Total Detraining Customers median  Total Detraining Customers std  \
# 0                            11074.0                       4863.7000
# 1                            11940.0                       5641.9565
#
#    Late Detraining Customers sum  Late Detraining Customers mean  \
# 0                         552773                       2372.4163
# 1                         515481                       5103.7723
#
#    Late Detraining Customers median  Late Detraining Customers std  \
# 0                            1899.0                      2133.4779
# 1                            4467.0                      3751.6213
#
#    Late to Total Detraining Customers Ratio  \
# 0                                    0.2064
# 1                                    0.4911
#
#    Late Detraining Customers Avg Min Late mean  \
# 0                                      47.3609
# 1                                     124.2222
#
#    Total On Time Detraining Customers sum
# 0                                 2125848
# 1                                  534060

# %% [markdown]
# #### 3.14.2 CHI: visualize distribution of mean late arrival times
#
# Illustrate with box plots.

# %%
chi_svc_lines = chi.groupby(COLS["svc_line"])[[COLS["svc_line"], COLS["late_detrn_avg_mm_late"]]]
chrt_data = chi_svc_lines.apply(lambda x: x).reset_index(drop=True)  # Flatten for Altair
chrt_data.head()
# Out:
#     Service Line  Late Detraining Customers Avg Min Late
# 0  Long Distance                                   137.0
# 1  Long Distance                                    75.0
# 2  Long Distance                                   123.0
# 3  Long Distance                                   145.0
# 4  Long Distance                                   114.0

# %%
title_txt = (
    f"Late Detraining Passengers: {text['Arrival Station']} ({text['Arrival Station Code']}), "
    f"{text['City']}, {text['State']}"
)
title = chrt.format_title(chi_stats, title_txt)

# Restrict Amtrak services to those that the station handles
amtk_svcs = pd.Series(chrt_data[COLS["svc_line"]].unique()).sort_values(ascending=False).tolist()

chart = (
    bxp_bld.BoxPlotBuilder(bxp.BoxplotChart(frame=chrt_data, title=title))
    .color(scale_domain=amtk_svcs)
    .build()
)
chart.display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 3.15 Los Angeles Union Station (LAX), Los Angeles, CA
#
# [Los Angeles Union Station](https://www.amtrak.com/stations/lax) ([LAX](https://www.amtrak.com/stations/lax)) serves the West Coast with
# connections to Amtrak's long distance routes.

# %%
lax = ntwk.by_station(stations, "LAX")
lax.shape
# Out:
# (220, 24)

# %% [markdown]
# ### 3.16 LAX: on-time performance metrics (entire period) [1 pt]
#
# LAX station performance data is a compilation of quarterly metrics that focus on late
# detraining passengers. Detraining assengers are considered on-time if they arrive at their
# destination no later than fifteen (`15`) minutes after their scheduled arrival time. All other
# detraining passengers are considered late.

# %%
# Train arrivals (total)
lax_trn_arrivals = lax.shape[0]

# Detraining totals
lax_detrn = lax[COLS["total_detrn"]].sum()
lax_detrn_late = lax[COLS["late_detrn"]].sum()  # ← tambahkan .sum()
lax_detrn_on_time = lax_detrn - lax_detrn_late

print(
    f"Train Arrivals: {lax_trn_arrivals}",
    f"Total Detraining Customers: {lax_detrn}",
    f"Late Detraining Customers: {lax_detrn_late}",
    f"On-Time Detraining Customers: {lax_detrn_on_time}",
    sep="\n",
)

lax_stats = detrn.get_sum_stats(lax, AGG["columns"], AGG["funcs"])
lax_stats
# Out:
# Train Arrivals: 220
# Total Detraining Customers: 1383151
# Late Detraining Customers: 0      2584
# 1      6807
# 2      1942
# 3      1554
# 4      1830
#        ...
# 215    1563
# 216    1021
# 217    1662
# 218     226
# 219     287
# Name: Late Detraining Customers, Length: 220, dtype: int64
# On-Time Detraining Customers: 0      1380567
# 1      1376344
# 2      1381209
# 3      1381597
# 4      1381321
#         ...
# 215    1381588
# 216    1382130
# 217    1381489
# 218    1382925
# 219    1382864
# Name: Late Detraining Customers, Length: 220, dtype: int64
#    Train Arrivals  Total Detraining Customers sum  \
# 0             220                       1383151.0
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                          6287.05                             5750.0
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                        3558.478                       298156.0
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                       1355.2545                             892.0
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                      1460.4418                                    0.2156
#
#   Late Detraining Customers Avg Min Late mean  \
# 0                                        None
#
#    Total On Time Detraining Customers sum
# 0                               1084995.0

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 3.17 LAX: mean late arrival times summary statistics
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of LAX trains. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics.

# %%
# Drop missing values
lax_avg_mm_late = lax[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Call the custom frm.describe_numeric_column() function again
lax_avg_mm_late_describe = frm.describe_numeric_column(lax_avg_mm_late)
lax_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(213),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(63.6150234741784),
#   'median': 45.0,
#   'mode': np.float64(34.0)},
#  'position': {'min': np.float64(16.0),
#   '25%': np.float64(34.0),
#   '50%': np.float64(45.0),
#   '75%': np.float64(65.0),
#   'max': np.float64(383.0)},
#  'spread': {'variance': 2711.992603419258,
#   'std': 52.076795249124714,
#   'range': 367.0,
#   'iqr': np.float64(31.0)},
#  'shape': {'skewness': np.float64(2.536460931553542),
#   'kurtosis': np.float64(8.204368446736076)}}

# %% [markdown]
# ### 3.18 LAX: visualize distribution of mean late arrival times
#
# Visualize mean late arrival times for the entire period. The data is binned prior to plotting.
#
# #### 3.18.1 Create chart data [1 pt]

# %%
# Convert to DataFrame
lax_avg_mm_late = lax_avg_mm_late.to_frame(name=COLS["avg_mm_late"])

# Get mean and standard deviation
mu = lax_avg_mm_late_describe["center"]["mean"]  # ← sudah ada ["mean"]
sigma = lax_avg_mm_late_describe["spread"]["std"]

# Get max value (for x-axis ticks); pad max value for chart display
max_val = lax_avg_mm_late_describe["position"]["max"]
max_val_ceil = (np.ceil(max_val / 10) * 10).astype(float)

# Create bins
lax_mm_late, bins, num_bins, bin_width = frm.create_bins(lax_avg_mm_late, COLS["avg_mm_late"], 10)

# Bin the data
chrt_data = frm.bin_data(lax_mm_late, COLS["avg_mm_late"], bins)

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 3.18.2 Generate the histogram

# %%
title = chrt.format_title(lax_stats, f"Late Detraining Passengers: {STNS['lax']}")

chart = (
    hst_bld.HistogramBuilder(hst.HistogramChart(frame=chrt_data, title=title))
    .x(
        axis_tick_count=max_val_ceil,
        axis_values=np.arange(0.0, max_val_ceil + 15, 5).tolist(),  # Use np.arange for array of float values
        bin_max_bins=num_bins,
        bin_step=bin_width,
        scale_domain=[0.0, max_val_ceil],
    )
    .mu_rule(mu=mu)
    .sigma_rules(sigma=sigma, n=2)
    .build()
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### 3.19 LAX: on-time performance metrics (by fiscal year and quarter)
#
# Compute OTP summary statistics per fiscal year and quarter. Add quarterly train arrival metrics to
# the `DataFrame` named `lax_qtr_stats`.

# %%
lax_qtr_stats = detrn.get_sum_stats_by_group(
    lax,
    [COLS["year"], COLS["quarter"]],
    AGG["columns"],
    AGG["funcs"],
    lax_trn_arrivals,
    lax_detrn,
)
lax_qtr_stats.sort_values(by=[COLS["year"], COLS["quarter"]], ascending=[True, True])
# Out:
#     Fiscal Year  Fiscal Quarter  Train Arrivals  Train Arrival Ratio  \
# 0          2021               4              14             0.063636
# 1          2022               1              25             0.113636
# 2          2022               2              18             0.081818
# 3          2022               3              17             0.077273
# 4          2022               4              18             0.081818
# 5          2023               1              14             0.063636
# 6          2023               2              16             0.072727
# 7          2023               3              20             0.090909
# 8          2023               4              21             0.095455
# 9          2024               1              18             0.081818
# 10         2024               2              19             0.086364
# 11         2024               3              20             0.090909
#
#     Detraining Ratio  Total Detraining Customers sum  \
# 0           0.054844                           75858
# 1           0.079270                          109642
# 2           0.065893                           91140
# 3           0.098682                          136492
# 4           0.108741                          150405
# 5           0.070757                           97868
# 6           0.058466                           80867
# 7           0.074609                          103195
# 8           0.098950                          136863
# 9           0.102530                          141815
# 10          0.079227                          109583
# 11          0.108031                          149423
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                         5418.4286                             5507.5
# 1                         4385.6800                             3756.0
# 2                         5063.3333                             4760.5
# 3                         8028.9412                             7901.0
# 4                         8355.8333                             8667.5
# 5                         6990.5714                             7146.5
# 6                         5054.1875                             5103.0
# 7                         5159.7500                             5559.5
# 8                         6517.2857                             5709.0
# 9                         7878.6111                             7263.5
# 10                        5767.5263                             6867.0
# 11                        7471.1500                             7640.5
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                        2317.0101                          11456
# 1                        3322.4681                          23767
# 2                        2846.3386                          18051
# 3                        3622.6644                          31514
# 4                        4234.1648                          42910
# 5                        2650.9018                          20476
# 6                        2881.4689                          18553
# 7                        3146.4702                          24261
# 8                        3998.5819                          33286
# 9                        3403.2550                          24637
# 10                       3188.7364                          20676
# 11                       3901.2909                          28569
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                         818.2857                             847.0
# 1                         950.6800                             559.0
# 2                        1002.8333                             910.5
# 3                        1853.7647                            1444.0
# 4                        2383.8889                            1854.5
# 5                        1462.5714                             831.0
# 6                        1159.5625                             902.5
# 7                        1213.0500                             769.0
# 8                        1585.0476                            1351.0
# 9                        1368.7222                             953.5
# 10                       1088.2105                             663.0
# 11                       1428.4500                             767.5
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                        528.6046                                    0.1510
# 1                       1110.7817                                    0.2168
# 2                        840.6817                                    0.1981
# 3                       1828.8681                                    0.2309
# 4                       2174.2089                                    0.2853
# 5                       1471.1409                                    0.2092
# 6                       1051.6684                                    0.2294
# 7                       1524.1680                                    0.2351
# 8                       1641.1900                                    0.2432
# 9                       1236.8138                                    0.1737
# 10                      1373.8236                                    0.1887
# 11                      1587.2174                                    0.1912
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       43.2143
# 1                                       72.9091
# 2                                       68.9412
# 3                                       74.5294
# 4                                       62.8235
# 5                                       60.7857
# 6                                       62.0000
# 7                                       58.5263
# 8                                       63.2857
# 9                                       54.8333
# 10                                      59.1053
# 11                                      75.7895
#
#     Total On Time Detraining Customers sum
# 0                                    64402
# 1                                    85875
# 2                                    73089
# 3                                   104978
# 4                                   107495
# 5                                    77392
# 6                                    62314
# 7                                    78934
# 8                                   103577
# 9                                   117178
# 10                                   88907
# 11                                  120854

# %% [markdown]
# #### 3.19.1 Write to file [1 pt]
#
# Write `lax_qtr_stats` to a CSV file named `stu-amtk-lax_qtr_stats.csv`. Store the file in the
# `data/student` directory. Then compare it to the accompanying `fxt-amtk-lax_qtr_stats.csv` file. It
# must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk-lax_qtr_stats.csv")
lax_qtr_stats.to_csv(filepath)

# %%
# hidden tests are within this cell

# %% [markdown]
# ### 3.20 LAX: visualize detraining passengers
#
# Visualize LAX detraining passengers, both on-time and late, across all years and quarters with a
# bar chart.

# %%
# Assemble the data for the chart
chrt_data = detrn.create_detrain_chart_frame(lax_qtr_stats, CHRT_BAR["columns"])

# Get station code, station name, city, and state to use in the chart title
text = frm.drop_dups_and_squeeze(
    lax, [COLS["station_code"], COLS["station"], COLS["city"], COLS["state"]]
)

# Chart title
title_txt = (
    f"Detraining Passengers: {text['Arrival Station']} ({text['Arrival Station Code']}), "
    f"{text['City']}, {text['State']}"
)
title = chrt.format_title(lax_stats, title_txt)

chart = bar_bld.GrpBarBuilder(bar.GrpBarChart(frame=chrt_data, title=title)).build()
chart.display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 3.21 LAX: On-time performance metrics by service line [1 pt]
#
# Group train arrivals by service line.

# %%
lax_svc_trains = lax.groupby(COLS["svc_line"]).size().reset_index()  # Includes rows with NaN
lax_svc_trains.columns = [COLS["svc_line"], COLS["trn_arrivals"]]
lax_svc_trains.sort_values(by=COLS["trn_arrivals"], ascending=False, inplace=True)  # ← tambahkan inplace=True
lax_svc_trains.reset_index(drop=True, inplace=True)

# Add train arrival ratios (year_qtr/total)
lax_svc_trains.loc[:, COLS["trn_arrival_ratio"]] = (
    lax_svc_trains[COLS["trn_arrivals"]] / lax_trn_arrivals
)
lax_svc_trains
# Out:
#       Service Line  Train Arrivals  Train Arrival Ratio
# 0    Long Distance              37             0.168182
# 1  State Supported             183             0.831818

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 3.21.1 LAX: compute on-time performance metrics by service line. [1 pt]

# %%
# Get summary stats by COLS["svc_line"]
lax_svc_line_stats = detrn.get_sum_stats_by_group(
    lax, COLS["svc_line"], AGG["columns"], AGG["funcs"]
)

# Merge train arrivals by service line
lax_svc_line_stats = lax_svc_line_stats.merge(lax_svc_trains, on=COLS["svc_line"], how="inner")

# Move train arrival columns
cols = lax_svc_line_stats.columns.tolist()
cols = [cols[0]] + cols[-2:] + cols[1:-2]
lax_svc_line_stats = lax_svc_line_stats[cols]

# Add service line detraining ratios
lax_svc_line_stats.loc[:, "Service Line Detraining Ratio"] = (
    lax_svc_line_stats["Total Detraining Customers sum"] / lax_detrn
)

# Sort by passengers detrained (descending order)
lax_svc_line_stats.sort_values(by="Total Detraining Customers sum", ascending=False, inplace=True)

# Setelah sort, tambahkan insert kolom seperti pada nyp/chi:
lax_svc_line_stats.insert(
    3, "Service Line Detraining Ratio", lax_svc_line_stats.pop("Service Line Detraining Ratio")
)

# Reset index
lax_svc_line_stats.reset_index(drop=True, inplace=True)
lax_svc_line_stats
# Out:
#       Service Line  Train Arrivals_y  Train Arrival Ratio  Train Arrivals_x  \
# 0  State Supported               183             0.831818               183
# 1    Long Distance                37             0.168182                37
#
#    Total Detraining Customers sum  Total Detraining Customers mean  \
# 0                         1141156                        6235.8251
# 1                          241995                        6540.4054
#
#    Total Detraining Customers median  Total Detraining Customers std  \
# 0                             5738.0                       3631.4116
# 1                             6422.0                       3206.8904
#
#    Late Detraining Customers sum  Late Detraining Customers mean  \
# 0                         177029                        967.3716
# 1                         121127                       3273.7027
#
#    Late Detraining Customers median  Late Detraining Customers std  \
# 0                             762.0                       856.1848
# 1                            2787.0                      2172.9277
#
#    Late to Total Detraining Customers Ratio  \
# 0                                    0.1551
# 1                                    0.5005
#
#    Late Detraining Customers Avg Min Late mean  \
# 0                                      46.9605
# 1                                     145.5000
#
#    Total On Time Detraining Customers sum  Service Line Detraining Ratio
# 0                                  964127                       0.825041
# 1                                  120868                       0.174959

# %%
# hidden tests are within this cell

# %% [markdown]
# #### 3.21.2 LAX: visualize distribution of mean late arrival times
#
# Illustrate with box plots.

# %%
lax_svc_lines = lax.groupby(COLS["svc_line"])[[COLS["svc_line"], COLS["late_detrn_avg_mm_late"]]]
chrt_data = lax_svc_lines.apply(lambda x: x).reset_index(drop=True)
chrt_data.head()
# Out:
#     Service Line  Late Detraining Customers Avg Min Late
# 0  Long Distance                                   134.0
# 1  Long Distance                                   165.0
# 2  Long Distance                                   239.0
# 3  Long Distance                                    80.0
# 4  Long Distance                                   157.0

# %%
title_txt = (
    f"Late Detraining Passengers: {text['Arrival Station']} ({text['Arrival Station Code']}), "
    f"{text['City']}, {text['State']}"
)
title = chrt.format_title(lax_stats, title_txt)

# Restrict Amtrak services to only those that the station handles
amtk_svcs = pd.Series(chrt_data[COLS["svc_line"]].unique()).sort_values(ascending=False).tolist()

chart = (
    bxp_bld.BoxPlotBuilder(bxp.BoxplotChart(frame=chrt_data, title=title))
    .color(scale_domain=amtk_svcs)
    .build()
)
chart.display()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 3.0 Watermark

# %%
# %load_ext watermark
# %watermark -h -i -iv -m -v
# Out:
# Python implementation: CPython
# Python version       : 3.11.9
# IPython version      : 8.26.0
#
# Compiler    : GCC 12.3.0
# OS          : Linux
# Release     : 6.5.0-1024-aws
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit
#
# Hostname: e3ef964e1464
#
# numpy : 2.1.3
# pandas: 2.2.3
# scipy : 1.13.0
